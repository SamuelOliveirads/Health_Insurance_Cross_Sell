# %% [markdown]
# # 0.0 Imports

# %%
import pickle
import warnings

import numpy as np
import pandas as pd
import seaborn as sns
import psycopg2 as pg
import scikitplot as skplt
import matplotlib.patches as mpatches

from tabulate import tabulate
from pycorrcat import pycorrcat
from IPython.display import HTML
from IPython.display import Image
from matplotlib import pyplot as plt
from matplotlib.gridspec import GridSpec
from credentials.credentialsdb import acess

from xgboost import XGBClassifier
from sklearn import ensemble as en
from sklearn import neighbors as nh
from lightgbm import LGBMClassifier
from imblearn import ensemble as ien
from sklearn import linear_model as lm
from sklearn import preprocessing as pp
from sklearn import model_selection as ms

from skopt.space import Real, Integer
from skopt.utils import use_named_args
from skopt import gp_minimize
from skopt.callbacks import CheckpointSaver

# %% [markdown]
# ## 0.1 Helper Functions

# %%
def jupyter_settings():
    '''Define configurations for jupyter notebook, matplotlib and Pandas.'''
    # %matplotlib inline
    plt.style.use('bmh')
    plt.rcParams['figure.figsize'] = [25,12]
    plt.rcParams['font.size'] = 24
    plt.rcParams['figure.dpi'] = 100
    
    display( HTML( '<style>.container{width:100% !important; }</style>'))
#    pd.options.display.max_columns = None
#   pd.options.display.max_rows = None
#    pd.set_option('display.expand_frame_repr', False)
    # configura o pandas para quantidade de casas decimeis
    pd.set_option('display.float_format', lambda x: '%.3f' % x)
    
    # ignora future warnings
    warnings.filterwarnings('ignore')
    
    sns.set()


def precision_recall_at_k( data, k=20000 ):
    '''
    Calculate metrics of precision and recall for an total number of rankings (k)
    return tuple of precision and recall, return dataframe with ranking
    '''
    # reset index
    data = data.reset_index( drop=True )

    # create ranking order
    data['ranking'] = data.index + 1 

    data['precision_at_k'] = data['response'].cumsum() / data['ranking']

    data['recall_at_k'] = data['response'].cumsum() / data['response'].sum()

    return ((data.loc[k, 'precision_at_k'], data.loc[k, 'recall_at_k']), data)


def gain_lift_curve(yhat, yval, plot = True):
    '''
    plots gain and lift curve, respectively
    returns the curves and a table used to plot the curves
    '''

    # create table proba with the propensity score for each class (0 and 1)
    table_proba = pd.DataFrame(yhat)

    # add the 'response' column
    table_proba['response'] = yval.values

    # add the 'correct' column to evaluate wheter the prediction was right or not
    x = lambda x: "yes" if x[0] > x[1] and x['response'] == 0 else "yes" if x[1] > x[0] and x['response'] == 1 else "yes" if x[0] == x[1] else "no" 
    table_proba['correct'] = table_proba.apply(x, axis = 1)

    # order by propensity score for the class 1
    table_proba.sort_values(1, ascending = False, inplace = True)

    # create cumulative propensity score
    ## calculate the quantity of class 1 rows
    qty_class_1 = table_proba.groupby('response').count().loc[1,1]

    ## apply a score for every row which response is 1
    x = lambda x: 1/qty_class_1 if x['response'] == 1 else 0
    table_proba['propensity_score'] = table_proba.apply(x, axis = 1)
    table_proba['cumulative_propensity_score'] = np.cumsum(table_proba['propensity_score'])

    # create % cumulative of the base
    x = lambda x: 1/len(table_proba)
    table_proba['porc_base'] = table_proba.apply(x, axis = 1)
    table_proba['cumulative_porc_base'] = np.cumsum(table_proba['porc_base'])
    table_proba.drop('porc_base', axis = 1, inplace = True)

    # create the lift column
    table_proba['lift'] = table_proba['cumulative_propensity_score'] / table_proba['cumulative_porc_base']

    if plot:
        fig, axes = plt.subplots(2, 1, figsize=(8, 10))

        # gap between graphics
        fig.tight_layout(pad =5)

        # gain curve
        sns.lineplot(ax = axes[0], x = table_proba['cumulative_porc_base'], y = table_proba['cumulative_propensity_score'], label="cumulative (model)", linewidth = 2.5);
        sns.lineplot(ax = axes[0], x = table_proba['cumulative_porc_base'], y = table_proba['cumulative_porc_base'], label="baseline", linewidth = 2.5, color = 'black' )
        axes[0].lines[1].set_linestyle("--")
        axes[0].legend()
        axes[0].set_title("cumulative gains curve")
        axes[0].set_xlabel("percentage of sample")
        axes[0].set_ylabel("gain")

        # lift curve
        ## do not consider the beginning of the series, as it varies a lot (the sample is still small)
        table_proba_filtered = table_proba.query('cumulative_porc_base >= 0.1')

        sns.lineplot(ax = axes[1], x = table_proba_filtered['cumulative_porc_base'], y = table_proba_filtered['lift'], label="model", linewidth = 2.5 );
        sns.lineplot(ax = axes[1], x = table_proba_filtered['cumulative_porc_base'], y = np.ones(len(table_proba_filtered)), label="baseline", linewidth = 2.5, color = 'black' )
        axes[1].lines[1].set_linestyle("--")
        axes[1].legend()
        axes[1].set_title("lift curve")
        axes[1].set_xlabel("percentage of sample")

        plt.show();
        
    return (table_proba)


def runCrossValidation(model, x_train, x_val_ml, y_train, y_val, n_splits, n_repeats, top_k = 20000, verbose=False):
    '''
    Make cross validation with parameters of total ranking (k)
    return a dataframe with metrics of precision and recall at k
    '''
    # local import
    from sklearn.model_selection import RepeatedStratifiedKFold

    
    if verbose:
        # the lenght_msg is to print only once a specific message
        length_msg = True
        i = 1
    
    # the seed usage provides repeatability 
    np.random.seed(1231234)
    
    # it is necessary to join the train and validation datasets
    x = pd.concat([x_train, x_val_ml])
    y = pd.concat([y_train, y_val])
    
    
    # definition of the cross-validation strategy
    # - the "n_splits" parameter is the number of folds (k)
    # - the "n_repeats" parameter is the number of times cross-validator needs to 
    #   be repeated
    cv = RepeatedStratifiedKFold(n_splits = n_splits, n_repeats = n_repeats )
    
    precision_at_k = []
    recall_at_k = []
    
    for train_index, prim_val_index in cv.split(x, y):      
        x_training, x_prim_val = x.iloc[train_index], x.iloc[prim_val_index]
        y_training, y_prim_val = y.iloc[train_index], y.iloc[prim_val_index]
        
        if (verbose == True) and (length_msg == True):
            print(f'training_lenght:{x_training.shape[0]}\nvalidation_lenght:{x_prim_val.shape[0]}\n\n')
            length_msg = False
        
        if verbose:
            print(f'Iteration number:{i}')
            i += 1

        # fit and predict_proba
        model.fit(x_training, y_training)
        yhat_proba = model.predict_proba(x_prim_val)
        
        # get results
        table = gain_lift_curve(yhat_proba,y_prim_val, plot = False)
        metrics, new_table = precision_recall_at_k(table, top_k)
        
        if verbose:
            print(metrics)
            print('')
        
        # save the metrics value to the list
        precision_at_k.append(metrics[0])
        recall_at_k.append(metrics[1])
        
    df_results = pd.DataFrame([[np.mean(precision_at_k),np.std(precision_at_k)], 
                       [np.mean(recall_at_k), np.std(recall_at_k)]],
                      columns = ["mean", "std"])
    
    df_results.index = ["precision_at_k","recall_at_k"]
    
    return(df_results)

# %%
jupyter_settings()
# Out:
# <style>.container{width:100% !important; }</style>

# %% [markdown]
# ## 0.2 Load Data

# %%
# Credentials
host = acess.get('host')
port = acess.get('port')
database = acess.get('database')
username = acess.get('username')
password = acess.get('password')

# acess database
conn = pg.connect(user=username,
                  password = password,
                  host = host,
                  port = port,
                  database = database)

# make a cursor into database
cursor = conn.cursor()

# verify all schemas
query_schema = """
    SELECT nspname
    FROM pg_catalog.pg_namespace
    """

cursor.execute(query_schema)
record = cursor.fetchall()
record
# Out:
# [('pg_toast',),
#  ('pg_temp_1',),
#  ('pg_toast_temp_1',),
#  ('pg_catalog',),
#  ('information_schema',),
#  ('public',),
#  ('pa004',),
#  ('pg_temp_4',),
#  ('pg_toast_temp_4',),
#  ('pa005',),
#  ('pg_temp_9',),
#  ('pg_toast_temp_9',)]

# %%
# Verify tables from the schema
#query_tables = """
#    SELECT tablename
#    FROM pg_tables
#    WHERE schemaname='pa004'
#    """

#cursor.execute(query_tables)
#record = cursor.fetchall()
#record

# %%
# Collect tables into dataframe
query_tables_insurance = """
    SELECT *
    FROM pa004.users u INNER JOIN pa004.vehicle v ON (u.id = v.id)
                       INNER JOIN pa004.insurance i ON (u.id = i.id)
    """

df_raw = pd.read_sql(query_tables_insurance, conn)

# close connection into database
cursor.close()
conn.close()

# %% [markdown]
# # 1.0 Descrição dos dados

# %%
df1 = df_raw.copy()

# %%
# drop duplicates id columns
df1 = df1.loc[:, ~df1.columns.duplicated()].copy()
df1.head()
# Out:
#    id  gender  age  region_code  policy_sales_channel  driving_license  \
# 0   7    Male   23       11.000               152.000                1
# 1  13  Female   41       15.000                14.000                1
# 2  18  Female   25       35.000               152.000                1
# 3  31  Female   26        8.000               160.000                1
# 4  39    Male   45        8.000               124.000                1
#
#   vehicle_age vehicle_damage  previously_insured  annual_premium  vintage  \
# 0    < 1 Year            Yes                   0       23367.000      249
# 1    1-2 Year             No                   1       31409.000      221
# 2    < 1 Year             No                   1       46622.000      299
# 3    < 1 Year             No                   0        2630.000      136
# 4    1-2 Year            Yes                   0       42297.000      264
#
#    response
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# ## 1.2 Data Dimension

# %%
print(f'Number os rows: {df1.shape[0]}')
print(f'Number os cols: {df1.shape[1]}')
# Out:
# Number os rows: 381109
# Number os cols: 12

# %% [markdown]
# ## 1.3 Data Types

# %%
df1.dtypes
# Out:
# id                        int64
# gender                   object
# age                       int64
# region_code             float64
# policy_sales_channel    float64
# driving_license           int64
# vehicle_age              object
# vehicle_damage           object
# previously_insured        int64
# annual_premium          float64
# vintage                   int64
# response                  int64
# dtype: object

# %% [markdown]
# ## 1.4 Check NA

# %%
df1.isna().sum()
# Out:
# id                      0
# gender                  0
# age                     0
# region_code             0
# policy_sales_channel    0
# driving_license         0
# vehicle_age             0
# vehicle_damage          0
# previously_insured      0
# annual_premium          0
# vintage                 0
# response                0
# dtype: int64

# %% [markdown]
# ## 1.7 Descriptive Statistical

# %%
num_attributes = df1.select_dtypes(include=['int64', 'float64'])
cat_attributes = df1.select_dtypes(exclude=['int64', 'float64'])

# %% [markdown]
# ### 1.7.1 Numerical Attributes

# %%
# Central tendency and Dispersion
d1 = pd.DataFrame (num_attributes.apply( lambda x: x.max() - x.min() )).T
d2 = num_attributes.agg(['min', 'max', 'mean', 'median', 'std', 'skew', 'kurtosis'])

# concatenate
m2 = pd.concat([d1, d2]).T.reset_index()
m2.columns = ['attibutes', 'range', 'min', 'max', 'mean', 'median', 'std', 'skew', 'kurtosis']
m2 = m2[['attibutes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']]

m2
# Out:
#               attibutes      min        max      range       mean     median  \
# 0                    id    1.000 381109.000 381108.000 190555.000 190555.000
# 1                   age   20.000     85.000     65.000     38.823     36.000
# 2           region_code    0.000     52.000     52.000     26.389     28.000
# 3  policy_sales_channel    1.000    163.000    162.000    112.034    133.000
# 4       driving_license    0.000      1.000      1.000      0.998      1.000
# 5    previously_insured    0.000      1.000      1.000      0.458      0.000
# 6        annual_premium 2630.000 540165.000 537535.000  30564.390  31669.000
# 7               vintage   10.000    299.000    289.000    154.347    154.000
# 8              response    0.000      1.000      1.000      0.123      0.000
#
#          std    skew  kurtosis
# 0 110016.836  -0.000    -1.200
# 1     15.512   0.673    -0.566
# 2     13.230  -0.115    -0.868
# 3     54.204  -0.900    -0.971
# 4      0.046 -21.595   464.354
# 5      0.498   0.168    -1.972
# 6  17213.155   1.766    34.005
# 7     83.671   0.003    -1.201
# 8      0.328   2.302     3.299

# %% [markdown]
# ### 1.7.2 Categorical Attributes

# %%
cat_attributes.apply( lambda x: x.unique().shape[0])
# Out:
# gender            2
# vehicle_age       3
# vehicle_damage    2
# dtype: int64

# %%
plt.subplot (1, 3, 1)
sns.countplot(x='gender', data=df1)

plt.subplot (1, 3, 2)
sns.countplot(x='vehicle_age', data=df1)

plt.subplot (1, 3, 3)
sns.countplot(x='vehicle_damage', data=df1);

# %% [markdown]
# # 2.0 Feature Engineering

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1 MindMap Hypothesis

# %%
Image('F:/SamuelOliveiraAlvesd/Desktop/Data_Science/Projetos/Health_Insurance_Cross_Sell/reports/figures/Best_Customers_for_Car_Insurance.png')

# %% [markdown]
# ## 2.1.1 Hipóteses Veiculo

# %% [markdown]
# **1.** Pessoas que possuem carro mais caros possuem maior interesse em seguro
#
# **2.** Pessoas com carros de modelo popular possuem menos interesse em seguro
#
# **3.** Pessoas com carros comprados recentemente possuem maior interesse em seguro
#
# **4.** Pessoas que o carro já foi danificado possuem maior interesse em seguro em relação aos que não foram danificados

# %% [markdown]
# ## 2.1.2 Hipóteses Cliente

# %% [markdown]
# **1.** Pessoas com maiores salarios possuem mais interesse em seguros
#
# **2.** Pessoas mais velhas possuem maior interesse em seguro
#
# **3.** Pessoas com filhos possuem maior interesse em seguro
#
# **4.** Pessoas com familia possuem maior interesse em seguro

# %% [markdown]
# ## 2.1.3 Hipóteses Localização

# %% [markdown]
# **1.** Pessoas próximas de hospitais possuem mais interesse em seguro
#
# **2.** Pessoas em diferentes regiões possuem maior interesse em seguro

# %% [markdown]
# ## 2.1.4 Hipóteses Tempo

# %% [markdown]
# **1.** Pessoas com mais tempo com seguro tem maior interesse em outros seguros
#
# **2.** Pessoas possuem maior interesse em seguro no inverno.
#
# **3.** Pessoas possuem maior interesse em seguro nos dias de feriado
#
# **4.** Existe maior interesse em seguros com o passar dos anos.

# %% [markdown]
# ## 2.2 Lista final de hipóteses

# %% [markdown]
# **1.** Pessoas com carros comprados recentemente possuem maior interesse em seguro
#
# **2.** Pessoas que o carro já foi danificado possuem maior interesse em seguro
#
# **3.** Pessoas mais velhas possuem maior interesse em seguro
#
# **4.** Pessoas em melhores regiões possuem maior interesse em seguro
#
# **5.** Pessoas com mais tempo com seguro tem maior interesse em outros seguros

# %% [markdown]
# ## 2.3 Feature Engineering

# %%
# adjust format into vehicle age
df2['vehicle_age'] = df2['vehicle_age'].apply(lambda x: 'over_2_years' if x == '> 2 Years'
                                                        else 'between_1_2_year' if x == '1-2 Year'
                                                        else 'below_1_year')


# Convert categorical into numeric
df2['vehicle_damage'] = df2['vehicle_damage'].apply(lambda x: 1 if x=='Yes' else 0)

# %% [markdown]
# # 3.0 Filtragem de variáveis

# %%
df3 = df2.copy()

# %% [markdown]
# ## 3.1 Filtragem das linhas

# %%
# select only annual_premium bellow 65.000
df3 = df3[df3['annual_premium'] < 65000]

# %% [markdown]
# ## 3.2 Seleção das colunas

# %%
# Select only who has driving license
df3 = df3[df3['driving_license'] == 1]

# drop driving license column
df3.drop(columns='driving_license', inplace=True)

# %% [markdown]
# # 4.0 Análise exploratória dos dados

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1 Análise Univariada

# %% [markdown]
# ### 4.1.1 Response Variable

# %%
sns.countplot(x='response', data=df4);

# %% [markdown]
# ### 4.1.2 Numerical Variable

# %%
num_attributes = df4.select_dtypes(include='number')
num_attributes.hist(bins=25);

# %%
#policy_sales_channel
# count responses per channel
aux01 = df4[['policy_sales_channel', 'response']].groupby('policy_sales_channel').sum().reset_index()
aux02 = df4[['policy_sales_channel', 'response']].groupby('policy_sales_channel').count().reset_index()

# merge and make percentage
aux03 = pd.merge(aux01, aux02, how='inner', on='policy_sales_channel')
aux03['response_x'] = aux03.apply(lambda x: x['response_x'] / x['response_y'] * 100, axis=1)
aux03['response_y'] = aux03.apply(lambda x: 100 - x['response_x'], axis=1)

# plot
aux03.plot(x = 'policy_sales_channel', kind = 'bar', stacked = True);

# %%
sns.boxplot(x='response', y='policy_sales_channel', data=df4);

# %%
# previously_insured
pd.crosstab(df4['previously_insured'], df4['response']).apply(lambda x : x / x.sum(), axis=1)
# Out:
# response               0     1
# previously_insured
# 0                  0.775 0.225
# 1                  0.999 0.001

# %% [markdown]
# ### 4.1.3 Categorical Variable

# %%
# gender
plt.subplot (1, 3, 1)
sns.countplot(x='gender', data=df4)

# vehicle_age
plt.subplot (1, 3, 2)
sns.countplot(x='vehicle_age', data=df4)

# vehicle_damage
plt.subplot (1, 3, 3)
sns.countplot(x='vehicle_damage', data=df4);

# %% [markdown]
# ## 4.2 Análise Bivariada

# %% [markdown]
# ### H1. Pessoas com carros comprados recentemente possuem maior interesse em seguro
# **FALSA** Pessoas com carros antigos possuem maior interesse em seguro

# %%
# plot for absolute response per vehicle age
plt.subplot(1, 2, 1)

aux01 = df4[['vehicle_age', 'response']].groupby('vehicle_age').sum().reset_index()
sns.barplot(x='vehicle_age', y='response', data=aux01);

# plot for percentages response per vehicle age
ax = plt.subplot(1, 2, 2)

aux02 = pd.crosstab(df4['vehicle_age'], df4['response']).apply(lambda x: x / x.sum(), axis=1).reset_index()
columns = ['vehicle_age', 'response_0', 'response_1']
aux02.columns = columns
aux02 = aux02[['vehicle_age', 'response_1', 'response_0']]

aux02.plot(x = 'vehicle_age', kind = 'bar', stacked = True, ax=ax);

# %% [markdown]
# ### H2. Pessoas que o carro já foi danificado possuem maior interesse em seguro em relação aos que não foram danificados
# **VERDADEIRA** Pessoas que tiveram o carro danificado demontram maior interesse em seguro, entretanto a maioria ainda não prefere.

# %%
aux1 = pd.crosstab(df4['vehicle_damage'], df4['response'])
aux1.apply(lambda x: x / x.sum(), axis=1)
# Out:
# response           0     1
# vehicle_damage
# 0              0.995 0.005
# 1              0.763 0.237

# %%
aux1.plot(kind='bar');

# %% [markdown]
# ### H3. Pessoas mais velhas possuem maior interesse em seguro
# **FALSO** Pessoas mais velhas possuem menor interesse em seguro a partir de 40 anos.

# %%
plt.subplot(1, 3, 1)
aux1 = df4[['age', 'response']].groupby('age').sum().reset_index()
sns.barplot(x='age', y='response', data=aux1)
plt.xticks(rotation=90)

plt.subplot(1, 3, 2)
sns.boxplot(x='response', y='age', data=df4)

plt.subplot(1, 3, 3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### H4. Pessoas em diferentes regiões possuem maior interesse em seguro
# **VERDADEIRA** Existem regiões com maiores interesse em seguro.

# %%
plt.subplot(1, 3, 1)
aux1 = df4[['region_code', 'response']].groupby('region_code').sum().reset_index()
aux2 = aux1[aux1['response'] < 4000]

sns.barplot(x='region_code', y='response', data=aux2)

plt.subplot(1, 3, 2)
sns.boxplot(x='response', y='region_code', data=df4)

plt.subplot(1, 3, 3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### H5. Pessoas com mais tempo com seguro tem maior interesse em outros seguros
# **FALSA** Pessoas com maior tempo de seguro são indiferentes das com menores tempos.

# %%
plt.subplot(1, 3, 1)
aux1 = df4[['vintage', 'response']].groupby('vintage').sum().sort_values('vintage').reset_index()
bins = list(np.arange(0, 310, 10))
aux1['vintage_binned'] = pd.cut(aux1['vintage'], bins = bins)

sns.barplot(x='vintage_binned', y='response', data=aux1)


plt.subplot(1, 3, 2)
sns.boxplot(x='response', y='vintage', data=df4)

plt.subplot(1, 3, 3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### 4.2.1 Resumo das Hipóteses

# %%
tab = [['Hipóteses', 'Conclusão', 'Relevância'],
       ['H1', 'Falsa', 'Baixa'],
       ['H2', 'Verdadeira', 'Médio'],
       ['H3', 'Falsa', 'Alto'],
       ['H4', 'Verdadeira', 'Baixa'],
       ['H5', 'Falsa', 'Baixa'],
      ]
print(tabulate(tab, headers='firstrow'))
# Out:
# Hipóteses    Conclusão    Relevância
# -----------  -----------  ------------
# H1           Falsa        Baixa
# H2           Verdadeira   Médio
# H3           Falsa        Alto
# H4           Verdadeira   Baixa
# H5           Falsa        Baixa

# %% [markdown]
# ## 4.3 Análise Multivariada

# %% [markdown]
# ### 4.3.1 Atributos numéricos

# %%
correlation = num_attributes.corr(method='pearson')
sns.heatmap(correlation, annot=True);

# %% [markdown]
# ### 4.3.2 Atributos categóricos

# %%
# only categorical data
a = df4.select_dtypes(include='object')

# Cramer V correlation
d = pycorrcat.corr_matrix(a, ['gender', 'vehicle_age'])
sns.heatmap(d, annot=True);

# %% [markdown]
# # 5.0 Preparação dos dados

# %%
X = df4.drop('response', axis=1)
y = df4['response'].copy()

x_train, x_val, y_train, y_val = ms.train_test_split(X, y, test_size=0.20)

df5 = pd.concat([x_train, y_train], axis=1)

# %% [markdown]
# ## 5.1 Standardization

# %%
ss = pp.StandardScaler()

# annual_premium
df5['annual_premium'] = ss.fit_transform(df5[['annual_premium']].values)

# %% [markdown]
# ## 5.2 Rescaling

# %%
mms_age = pp.MinMaxScaler()
mms_vintage = pp.MinMaxScaler()

# Age
df5['age'] = mms_age.fit_transform(df5[['age']].values)

# Vintage
df5['vintage'] = mms_vintage.fit_transform(df5[['vintage']].values)

# %% [markdown]
# ## 5.3 Transformação

# %% [markdown]
# ### 5.3.1 Encoding

# %%
# gender - Target Encoding
target_encode_gender = df5.groupby('gender')['response'].mean()
df5.loc[:, 'gender'] = df5['gender'].map(target_encode_gender)

# region_code - Target Encoding
target_encode_region_code = df5.groupby('region_code')['response'].mean()
df5.loc[:, 'region_code'] = df5['region_code'].map(target_encode_region_code)

# vehicle_age - One Hot Encoding
df5 = pd.get_dummies(df5, prefix='vehicle_age', columns=['vehicle_age'])

# policy_sales_channel - Frequency Encoding
fe_policy_sales_channel = df5.groupby('policy_sales_channel').size() / len(df5)
df5.loc[:, 'policy_sales_channel'] = df5['policy_sales_channel'].map(fe_policy_sales_channel)

# %% [markdown]
# # 6.0 Feature Selection

# %% [markdown]
# ## 6.1 Validation data preparation

# %%
# annual_premium
x_val.loc[:, 'annual_premium'] = ss.transform(x_val[['annual_premium']].values)

# Age
x_val.loc[:, 'age'] = mms_age.transform(x_val[['age']].values)

# Vintage
x_val.loc[:, 'vintage'] = mms_vintage.transform(x_val[['vintage']].values)

# gender - Target Encoding
x_val.loc[:, 'gender'] = x_val.loc[:, 'gender'].map(target_encode_gender)

# region_code - Target Encoding
x_val.loc[:, 'region_code'] = x_val.loc[:, 'region_code'].map(target_encode_region_code)

# vehicle_age - One Hot Encoding
x_val = pd.get_dummies(x_val, prefix='vehicle_age', columns=['vehicle_age'])

# policy_sales_channel - Frequency Encoding
x_val.loc[:, 'policy_sales_channel'] = x_val.loc[:, 'policy_sales_channel'].map(fe_policy_sales_channel)

# fillna
x_val = x_val.fillna(0)

# %% [markdown]
# ## 6.2 feature selection per importance

# %%
# model definition
#forest = en.ExtraTreesClassifier(n_estimators=250, random_state=0, n_jobs=-1)

# saving model
#pickle.dump(forest, open('F:/SamuelOliveiraAlvesd/Desktop/Data_Science/Projetos/Health_Insurance_Cross_Sell/models/extra_tree_selector.pkl', 'wb'))

# %%
# loading model selector
file = open('F:/SamuelOliveiraAlvesd/Desktop/Data_Science/Projetos/Health_Insurance_Cross_Sell/models/extra_tree_selector.pkl','rb')
forest = pickle.load(file)
file.close()


# data preparation
x_train_f = df5.drop(['id', 'response'], axis=1)
y_train_f = y_train.values
forest.fit(x_train_f, y_train_f)
# Out:
# ExtraTreesClassifier(n_estimators=250, n_jobs=-1, random_state=0)

# %%
# Collect features from model selector
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Organize and print ranking per features
print('Feature ranking:')
df = pd.DataFrame()
for i, j in zip(x_train_f, forest.feature_importances_):
    aux = pd.DataFrame({'feature': i, 'importance': j}, index=[0])
    df = pd.concat([df, aux], axis=0)

print(df.sort_values('importance', ascending=False))

# plot the impurity-based feature importances of the forest
plt.figure()
plt.title('Feature importances')
plt.bar(range(x_train_f.shape[1]), importances[indices], color='r', yerr=std[indices], align='center')
plt.xticks(range(x_train_f.shape[1]), indices)
plt.xlim([-1, x_train_f.shape[1]])
plt.show()
# Out:
# Feature ranking:
#                         feature  importance
# 0                       vintage       0.271
# 0                annual_premium       0.228
# 0                           age       0.175
# 0                   region_code       0.112
# 0                vehicle_damage       0.068
# 0          policy_sales_channel       0.063
# 0            previously_insured       0.056
# 0      vehicle_age_below_1_year       0.014
# 0  vehicle_age_between_1_2_year       0.007
# 0                        gender       0.006
# 0      vehicle_age_over_2_years       0.002

# %% [markdown]
# # 7.0 Machine Learning Modeling

# %%
# select features from ML
cols_selected = ['vintage', 'annual_premium', 'age', 'region_code',
                'vehicle_damage', 'policy_sales_channel', 'previously_insured']

# Dataframe for metrics
x_validation = x_val.copy()
y_validation = y_val.copy()

# Dataframe for ML
x_train = df5[cols_selected]
x_val = x_val[cols_selected]

# %% [markdown]
# ## 7.1 K-Nearest Neighbors

# %%
# model definition
knn_model = nh.KNeighborsClassifier(n_neighbors=7)

# model training
knn_model.fit(x_train, y_train)

# model prediction - Generalization
yhat_knn = knn_model.predict_proba(x_val)


# ---------- Metrics ------------------
# Accumulative gain
skplt.metrics.plot_cumulative_gain(y_val, yhat_knn);

# %% [markdown]
# ### 7.1.1 K-Nearest Neighbors - Cross-Validation

# %%
# making cross validation
#cv_knn = runCrossValidation(knn_model, x_train, x_val, y_train, y_val, n_splits=10, n_repeats=2, top_k = 20000, verbose=True)

# saving results
#pickle.dump(cv_knn, open('../data/processed/cv_knn.pkl', 'wb'))

# loading results
file = open('../data/processed/cv_knn.pkl','rb')
cv_knn = pickle.load(file)
file.close()

cv_knn
# Out:
#                 mean   std
# precision_at_k 0.204 0.001
# recall_at_k    0.896 0.004

# %% [markdown]
# ## 7.2 Logistic Regression

# %%
# model definition
lr_model = lm.LogisticRegression( random_state=42 ) 

# model training
lr_model.fit( x_train, y_train )

# model prediction
yhat_lr = lr_model.predict_proba( x_val )


# ---------- Metrics ------------------
# Accumulative Gain
skplt.metrics.plot_cumulative_gain( y_val, yhat_lr );

# %% [markdown]
# ### 7.2.1 Logistic Regression - Cross-Validation

# %%
# making cross validation
#cv_lr = runCrossValidation(lr_model, x_train, x_val, y_train, y_val, n_splits=10, n_repeats=2, top_k = 20000, verbose=True)

# saving results
#pickle.dump(cv_lr, open('../data/processed/cv_lr.pkl', 'wb'))

# loading results
file = open('../data/processed/cv_lr.pkl','rb')
cv_lr = pickle.load(file)
file.close()

cv_lr
# Out:
#                 mean   std
# precision_at_k 0.226 0.000
# recall_at_k    0.996 0.001

# %% [markdown]
# ## 7.3 Extra Trees

# %%
# model definition
#et_model = en.ExtraTreesClassifier(n_estimators=1000, n_jobs=-1, random_state=42) 

# model training
#et_model.fit( x_train, y_train )

# model prediction
#yhat_et = et_model.predict_proba( x_val )

# -------------- Saving and Loading model -------------------
# saving results
#pickle.dump(yhat_et, open('../models/yhat_et.pkl', 'wb'))

# loading results
file = open('../models/yhat_et.pkl','rb')
yhat_et = pickle.load(file)
file.close()

# ---------- Metrics ------------------
# Accumulative Gain
#skplt.metrics.plot_cumulative_gain( y_val, yhat_et );

# %% [markdown]
# ### 7.3.1 Extra Trees - Cross-Validation

# %%
# making cross validation
#cv_et = runCrossValidation(et_model, x_train, x_val, y_train, y_val, n_splits=10, n_repeats=2, top_k = 20000, verbose=True)

# saving results
#pickle.dump(cv_et, open('../data/processed/cv_et.pkl', 'wb'))

# loading results
file = open('../data/processed/cv_et.pkl','rb')
cv_et = pickle.load(file)
file.close()

cv_et
# Out:
#                 mean   std
# precision_at_k 0.225 0.000
# recall_at_k    0.989 0.002

# %% [markdown]
# ## 7.4 XGBoost

# %%
# model definition
#xgb_model = XGBClassifier(n_estimators=1000, n_jobs=-1, random_state=42)

# model training
#xgb_model.fit( x_train, y_train )

# model prediction
#yhat_xgb = xgb_model.predict_proba( x_val )


# ---------- Metrics ------------------
# Accumulative Gain
#skplt.metrics.plot_cumulative_gain( y_val, yhat_xgb );

# %% [markdown]
# ### 7.4.1 XGBoost - Cross-Validation

# %%
# making cross validation
#cv_xgb = runCrossValidation(xgb_model, x_train, x_val, y_train, y_val, n_splits=10, n_repeats=2, top_k = 20000, verbose=True)

# saving results
#pickle.dump(cv_xgb, open('../data/processed/cv_xgb.pkl', 'wb'))

# loading results
file = open('../data/processed/cv_xgb.pkl','rb')
cv_xgb = pickle.load(file)
file.close()

cv_xgb
# Out:
#                 mean   std
# precision_at_k 0.226 0.000
# recall_at_k    0.995 0.001

# %% [markdown]
# ## 7.5 LGBM

# %%
# model definition
lgbm_model = LGBMClassifier(n_estimators=1000, n_jobs=-1, random_state=42)

# model training
lgbm_model.fit( x_train, y_train )

# model prediction
yhat_lgbm = lgbm_model.predict_proba( x_val )


# ---------- Metrics ------------------
# Accumulative Gain
skplt.metrics.plot_cumulative_gain( y_val, yhat_lgbm );

# %% [markdown]
# ### 7.5.1 LGBM - Cross-Validation

# %%
# making cross validation
#cv_lgbm = runCrossValidation(lgbm_model, x_train, x_val, y_train, y_val, n_splits=10, n_repeats=2, top_k=20000, verbose=True)

# saving results
#pickle.dump(cv_lgbm, open('../data/processed/cv_lgbm.pkl', 'wb'))

# loading results
file = open('../data/processed/cv_lgbm.pkl','rb')
cv_lgbm = pickle.load(file)
file.close()

cv_lgbm
# Out:
# training_lenght:335190
# validation_lenght:37244
#
#
# Iteration number:1
# (0.22533873306334684, 0.9912029909830657)
#
# Iteration number:2
# (0.2256387180640968, 0.9925225423356059)
#
# Iteration number:3
# (0.22533873306334684, 0.9912029909830657)
#
# Iteration number:4
# (0.22598870056497175, 0.9940620189135694)
#
# Iteration number:5
# (0.22588870556472176, 0.9938407391113067)
#
# Iteration number:6
# (0.2255887205639718, 0.9925208974923009)
#
# Iteration number:7
# (0.22543872806359683, 0.9916428414339125)
#
# Iteration number:8
# (0.22588870556472176, 0.9936221684627227)
#
# Iteration number:9
# (0.22538873056347183, 0.9914229162084891)
#
# Iteration number:10
# (0.22543872806359683, 0.9916428414339125)
#
# Iteration number:11
# (0.2256887155642218, 0.9927424675610292)
#
# Iteration number:12
# (0.22583870806459677, 0.9934022432372993)
#
# Iteration number:13
# (0.2256887155642218, 0.9927424675610292)
#
# Iteration number:14
# (0.22538873056347183, 0.9914229162084891)
#
# Iteration number:15
# (0.2255387230638468, 0.9923009238891333)
#
# Iteration number:16
# (0.22538873056347183, 0.9916410030796304)
#
# Iteration number:17
# (0.22518874056297186, 0.9905432153067957)
#
# Iteration number:18
# (0.22578871056447178, 0.993182318011876)
#
# Iteration number:19
# (0.22528873556322185, 0.9909830657576424)
#
# Iteration number:20
# (0.22608869556522174, 0.9945018693644161)
#                 mean   std
# precision_at_k 0.226 0.000
# recall_at_k    0.992 0.001

# %% [markdown]
# ## 7.6 Balanced Random Forest Classifier

# %%
# model definition
#brf_model = ien.BalancedRandomForestClassifier(n_estimators=1000, n_jobs=-1, random_state=42, sampling_strategy=0.14)

# model training
#brf_model.fit( x_train, y_train )

# model prediction
#yhat_brf = brf_model.predict_proba( x_val )

# -------------- Saving and Loading model -------------------
# saving results
#pickle.dump(yhat_brf, open('../models/yhat_brf.pkl', 'wb'))

# loading results
file = open('../models/yhat_brf.pkl','rb')
yhat_brf = pickle.load(file)
file.close()

# ---------- Metrics ------------------
# Accumulative Gain
skplt.metrics.plot_cumulative_gain( y_val, yhat_brf );

# %% [markdown]
# ### 7.6.1 Balanced Random Forest - Cross-Validation

# %%
# making cross validation
#cv_brf = runCrossValidation(brf_model, x_train, x_val, y_train, y_val, n_splits=10, n_repeats=2, top_k=20000, verbose=True)

# saving results
#pickle.dump(cv_brf, open('../data/processed/cv_brf.pkl', 'wb'))

# loading results
#file = open('../data/processed/cv_brf.pkl','rb')
#cv_brf = pickle.load(file)
#file.close()

#cv_brf

# %% [markdown]
# ## 7.6 Compare Model's Performance

# %% [markdown]
# ### 7.6.1 Single Performance

# %%
#model_list = {'KNN_model' : yhat_knn, 'Logistic_Regression' : yhat_lr, 'Extra_Trees_Classifier' : yhat_et, 'XGBoost' : yhat_xgb, 'LGBM' : yhat_lgbm, 'Balanced_RF' : yhat_brf}
#results = pd.DataFrame(columns=['model_name', 'precision_at_K', 'recall_at_K'])

#for n, m in model_list.items():
    # copy data
#    df8 = x_validation.copy()
#    df8['response'] = y_validation.copy()

    # propensity score
#    df8['score'] = m[:, 1].tolist()

    # sort clients by propensity score
#    df8 = df8.sort_values( 'score', ascending=False )

    # compute precision and recall at 20.000 k
#    metrics, data = precision_recall_at_k(df8)

#    metricst = metrics
#    metricst = pd.DataFrame(metricst)
#    metricst = metricst.T
#    metricst['model_name'] = n
#    metricst.columns = ['precision_at_K', 'recall_at_K', 'model_name']
#    metricst = metricst[['model_name', 'precision_at_K', 'recall_at_K']]
#    results = pd.concat([metricst, results])

# sort results
#results.sort_values('precision_at_K', ascending=False, inplace=True)

# saving results
#pickle.dump(results, open('../data/processed/ml_result.pkl', 'wb'))

# loading results
file = open('../data/processed/ml_result.pkl','rb')
ml_result = pickle.load(file)
file.close()

ml_result
# Out:
#                model_name  precision_at_K  recall_at_K
# 0                    LGBM           0.328        0.720
# 0                 XGBoost           0.320        0.701
# 0             Balanced_RF           0.310        0.679
# 0               KNN_model           0.290        0.635
# 0     Logistic_Regression           0.289        0.634
# 0  Extra_Trees_Classifier           0.121        0.265

# %% [markdown]
# ### 7.6.2 Real Performance - Cross Validation

# %%
#final_cv = pd.DataFrame()
#model_list = {'KNN_model' : cv_knn, 'Logistic_Regression' : cv_lr, 'Extra_Trees_Classifier' : cv_et, 'XGBoost' : cv_xgb, 'LGBM' : cv_lgbm}

#for n, m in model_list.items():
#    m[n] = m.apply(lambda x : (str(x['mean']))[:5] + '+/-' + (str(x['std']))[:5], axis=1)
#    m = m[[n]].T
#    m.reset_index(inplace=True)
#    m.columns = ['model_name', 'precision_at_k', 'recall_at_k']

#    final_cv = pd.concat([final_cv, m])

#final_cv.sort_values('precision_at_k', ascending=False, inplace=True)

# saving results
#pickle.dump(final_cv, open('../data/processed/ml_result_cv.pkl', 'wb'))

# loading results
file = open('../data/processed/ml_result_cv.pkl','rb')
ml_result_cv = pickle.load(file)
file.close()

ml_result_cv
# Out:
#                model_name precision_at_k    recall_at_k
# 0     Logistic_Regression  0.226+/-0.000  0.996+/-0.000
# 0                 XGBoost  0.226+/-0.000  0.994+/-0.001
# 0                    LGBM  0.226+/-0.000  0.996+/-0.001
# 0  Extra_Trees_Classifier  0.224+/-0.000  0.988+/-0.001
# 0               KNN_model  0.203+/-0.001  0.896+/-0.004

# %% [markdown]
# # 8.0 Hyper Parameter Fine Tunning

# %% [markdown]
# ## 8.1 Bayesian Search

# %%
# Search space for hyper parameters
#search_space = [Integer( 100, 1500, name = 'n_estimators'), 
#                Integer(1, 20, name = 'max_depth'), 
#                Real(0.001, 0.1, 'log-uniform', name = 'learning_rate'),
#                Integer(2, 128, name = 'num_leaves'),
#                Integer(1, 100, name = 'min_child_samples'),
#                Real(0.05, 1.0, name = 'subsample'),
#                Real(0.15, 1.0, name = 'colsample_bytree')]

# model definition
#lgbm_model = LGBMClassifier(n_jobs=-1, random_state=42, subsample_freq=1)

# applying cross-validation into tunning
#@use_named_args(search_space)
#def model_eval( **params ):
	
#    lgbm_model.set_params(**params)
#    print(lgbm_model)
#    ft_result = runCrossValidation(lgbm_model, x_train, x_val, y_train, y_val, n_splits=5, n_repeats=1, top_k=20000, verbose=False)
#    return -ft_result['mean'][0]

# create checkpoints
#checkpoint_callback = CheckpointSaver('../models/lgbm_ft.pkl')

# return results and run bayesian optimize
#result = gp_minimize( model_eval, search_space, n_calls = 30, 
#                      n_initial_points = 10, verbose=True, n_jobs=-1, 
#                      random_state= 42, callback=[checkpoint_callback])
#result
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.5403615581709872,
#                learning_rate=0.036256176345762295, max_depth=4,
#                min_child_samples=45, n_estimators=1215, num_leaves=77,
#                random_state=42, subsample=0.14497617002710278,
#                subsample_freq=1)
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 60.4517
# Function value obtained: -0.3296
# Current minimum: -0.3296
# Iteration No: 2 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.15066195096486218,
#                learning_rate=0.020034427927560734, max_depth=4,
#                min_child_samples=72, n_estimators=567, num_leaves=9,
#                random_state=42, subsample=0.9416250735649628, subsample_freq=1)
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 32.5814
# Function value obtained: -0.3196
# Current minimum: -0.3296
# Iteration No: 3 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.48988182595796725,
#                learning_rate=0.01672269700618368, max_depth=13,
#                min_child_samples=3, n_estimators=1489, num_leaves=3,
#                random_state=42, subsample=0.5485359272454697, subsample_freq=1)
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 59.7362
# Function value obtained: -0.3288
# Current minimum: -0.3296
# Iteration No: 4 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.9857462529357701,
#                learning_rate=0.0029210748185657135, max_depth=20,
#                min_child_samples=62, n_estimators=165, num_leaves=13,
#                random_state=42, subsample=0.41333889170380467,
#                subsample_freq=1)
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 19.7362
# Function value obtained: -0.3245
# Current minimum: -0.3296
# Iteration No: 5 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.6287949851687085,
#                learning_rate=0.022941144328643994, max_depth=17,
#                min_child_samples=2, n_estimators=753, num_leaves=59,
#                random_state=42, subsample=0.9450916679006104, subsample_freq=1)
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 48.8899
# Function value obtained: -0.3306
# Current minimum: -0.3306
# Iteration No: 6 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.8582156749757399,
#                learning_rate=0.002895927274708839, max_depth=1,
#                min_child_samples=69, n_estimators=640, num_leaves=32,
#                random_state=42, subsample=0.62949682489349, subsample_freq=1)
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 30.3507
# Function value obtained: -0.2845
# Current minimum: -0.3306
# Iteration No: 7 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.6325452786469928,
#                learning_rate=0.0023145798905204883, max_depth=8,
#                min_child_samples=43, n_estimators=343, num_leaves=97,
#                random_state=42, subsample=0.24754457972477945,
#                subsample_freq=1)
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 37.5242
# Function value obtained: -0.3292
# Current minimum: -0.3306
# Iteration No: 8 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.42755965348496006,
#                learning_rate=0.007934293594590601, max_depth=17,
#                min_child_samples=93, n_estimators=144, num_leaves=52,
#                random_state=42, subsample=0.7409083960635999, subsample_freq=1)
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 20.5969
# Function value obtained: -0.3290
# Current minimum: -0.3306
# Iteration No: 9 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.648738490814271,
#                learning_rate=0.08362652463906246, max_depth=11,
#                min_child_samples=75, n_estimators=899, num_leaves=108,
#                random_state=42, subsample=0.5627075257696259, subsample_freq=1)
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 79.5875
# Function value obtained: -0.3162
# Current minimum: -0.3306
# Iteration No: 10 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.5098912586004143,
#                learning_rate=0.0035644979070394624, max_depth=13,
#                min_child_samples=17, n_estimators=1451, num_leaves=39,
#                random_state=42, subsample=0.06485458640413425,
#                subsample_freq=1)
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 79.4256
# Function value obtained: -0.3303
# Current minimum: -0.3306
# Iteration No: 11 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.3049621543844617,
#                learning_rate=0.0015839790436456772, max_depth=20,
#                min_child_samples=100, n_estimators=1500, num_leaves=109,
#                random_state=42, subsample=0.3080912274705716, subsample_freq=1)
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 124.8307
# Function value obtained: -0.3219
# Current minimum: -0.3306
# Iteration No: 12 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.5424561201696069, learning_rate=0.001,
#                max_depth=13, min_child_samples=1, num_leaves=32,
#                random_state=42, subsample=0.05, subsample_freq=1)
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 15.9759
# Function value obtained: -0.3279
# Current minimum: -0.3306
# Iteration No: 13 started. Searching for the next optimal point.
# LGBMClassifier(learning_rate=0.006992341721255776, max_depth=17,
#                min_child_samples=93, n_estimators=1500, num_leaves=128,
#                random_state=42, subsample=0.4830908542567547, subsample_freq=1)
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 141.8003
# Function value obtained: -0.3283
# Current minimum: -0.3306
# Iteration No: 14 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.5915088632259466,
#                learning_rate=0.01437979949854321, max_depth=17,
#                min_child_samples=88, n_estimators=1500, num_leaves=67,
#                random_state=42, subsample_freq=1)
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 87.4390
# Function value obtained: -0.3301
# Current minimum: -0.3306
# Iteration No: 15 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.5612451612462592, max_depth=17,
#                min_child_samples=12, n_estimators=572, num_leaves=24,
#                random_state=42, subsample_freq=1)
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 31.7329
# Function value obtained: -0.3293
# Current minimum: -0.3306
# Iteration No: 16 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.5125157499136633,
#                learning_rate=0.002048647014132568, max_depth=8,
#                min_child_samples=22, n_estimators=417, num_leaves=124,
#                random_state=42, subsample=0.23287860697577578,
#                subsample_freq=1)
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 41.9209
# Function value obtained: -0.3296
# Current minimum: -0.3306
# Iteration No: 17 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.22406354984908483, learning_rate=0.001,
#                max_depth=9, min_child_samples=23, n_estimators=1459,
#                num_leaves=98, random_state=42, subsample=0.05,
#                subsample_freq=1)
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 111.5274
# Function value obtained: -0.3207
# Current minimum: -0.3306
# Iteration No: 18 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.318113647306532,
#                learning_rate=0.0011157837116082738, max_depth=8,
#                min_child_samples=98, n_estimators=1063, num_leaves=127,
#                random_state=42, subsample=0.09116268513049337,
#                subsample_freq=1)
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 76.5463
# Function value obtained: -0.3205
# Current minimum: -0.3306
# Iteration No: 19 started. Searching for the next optimal point.
# LGBMClassifier(learning_rate=0.050128928383632365, max_depth=5,
#                min_child_samples=1, n_estimators=1500, num_leaves=128,
#                random_state=42, subsample=0.05, subsample_freq=1)
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 88.4698
# Function value obtained: -0.3148
# Current minimum: -0.3306
# Iteration No: 20 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.4922918066634896,
#                learning_rate=0.04323943063649066, max_depth=20,
#                min_child_samples=100, n_estimators=1275, num_leaves=2,
#                random_state=42, subsample=0.18777440435310172,
#                subsample_freq=1)
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 44.0568
# Function value obtained: -0.3273
# Current minimum: -0.3306
# Iteration No: 21 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.6526530460379836,
#                learning_rate=0.09430139273361374, max_depth=13,
#                min_child_samples=100, n_estimators=298, num_leaves=43,
#                random_state=42, subsample=0.9645804610231924, subsample_freq=1)
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 25.6783
# Function value obtained: -0.3295
# Current minimum: -0.3306
# Iteration No: 22 started. Searching for the next optimal point.
# LGBMClassifier(learning_rate=0.03201817955523996, max_depth=4,
#                min_child_samples=97, n_estimators=829, num_leaves=99,
#                random_state=42, subsample=0.25955051608949153,
#                subsample_freq=1)
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 45.3911
# Function value obtained: -0.3303
# Current minimum: -0.3306
# Iteration No: 23 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.6560868239983404,
#                learning_rate=0.0024735625371492794, max_depth=8,
#                min_child_samples=1, num_leaves=2, random_state=42,
#                subsample=0.714722400827404, subsample_freq=1)
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 14.9125
# Function value obtained: -0.2725
# Current minimum: -0.3306
# Iteration No: 24 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.45023360627073417,
#                learning_rate=0.09822214069416192, max_depth=20,
#                min_child_samples=13, num_leaves=5, random_state=42,
#                subsample=0.9220548770045834, subsample_freq=1)
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 15.7120
# Function value obtained: -0.3281
# Current minimum: -0.3306
# Iteration No: 25 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.262119974433357,
#                learning_rate=0.013637676900103302, max_depth=1,
#                min_child_samples=3, num_leaves=74, random_state=42,
#                subsample=0.17179711106168544, subsample_freq=1)
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 13.9091
# Function value obtained: -0.2952
# Current minimum: -0.3306
# Iteration No: 26 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.9728248305081441,
#                learning_rate=0.019425618717147992, max_depth=13,
#                min_child_samples=35, n_estimators=1500, num_leaves=74,
#                random_state=42, subsample=0.2635250482474244, subsample_freq=1)
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 106.5545
# Function value obtained: -0.3251
# Current minimum: -0.3306
# Iteration No: 27 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.1629942013362983,
#                learning_rate=0.003923468774536708, max_depth=17,
#                min_child_samples=87, n_estimators=1224, num_leaves=87,
#                random_state=42, subsample=0.05, subsample_freq=1)
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 77.6446
# Function value obtained: -0.3165
# Current minimum: -0.3306
# Iteration No: 28 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.4003941954594421,
#                learning_rate=0.022807884678905585, max_depth=13,
#                min_child_samples=93, n_estimators=1500, num_leaves=62,
#                random_state=42, subsample=0.7703114587428822, subsample_freq=1)
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 105.6106
# Function value obtained: -0.3287
# Current minimum: -0.3306
# Iteration No: 29 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.5937655912607597,
#                learning_rate=0.0054566259766489315, max_depth=13,
#                min_child_samples=87, n_estimators=1500, num_leaves=2,
#                random_state=42, subsample=0.9084994568807491, subsample_freq=1)
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 54.2810
# Function value obtained: -0.3240
# Current minimum: -0.3306
# Iteration No: 30 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.7555484173420901, max_depth=13,
#                min_child_samples=48, n_estimators=560, num_leaves=127,
#                random_state=42, subsample=0.7494738464552517, subsample_freq=1)
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 48.7441
# Function value obtained: -0.3194
# Current minimum: -0.3306
#           fun: -0.33059347032648373
#     func_vals: array([-0.32958352, -0.31961402, -0.32876356, -0.32448378, -0.33059347,
#        -0.28451577, -0.32921354, -0.32900355, -0.31619419, -0.33026349,
#        -0.32186391, -0.3279036 , -0.32832358, -0.33012349, -0.32929354,
#        -0.32955352, -0.32068397, -0.32054397, -0.31482426, -0.32731363,
#        -0.32946353, -0.33028349, -0.27249638, -0.32813359, -0.29517524,
#        -0.32509375, -0.31654417, -0.32865357, -0.3240038 , -0.31941403])
#        models: [GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542)]
#  random_state: RandomState(MT19937) at 0x1ECABB47A40
#         space: Space([Integer(low=100, high=1500, prior='uniform', transform='normalize'),
#        Integer(low=1, high=20, prior='uniform', transform='normalize'),
#        Real(low=0.001, high=0.1, prior='log-uniform', transform='normalize'),
#        Integer(low=2, high=128, prior='uniform', transform='normalize'),
#        Integer(low=1, high=100, prior='uniform', transform='normalize'),
#        Real(low=0.05, high=1.0, prior='uniform', transform='normalize'),
#        Real(low=0.15, high=1.0, prior='uniform', transform='normalize')])
#         specs: {'args': {'func': <function model_eval at 0x000001ECACFB05E0>, 'dimensions': Space([Integer(low=100, high=1500, prior='uniform', transform='normalize'),
#        Integer(low=1, high=20, prior='uniform', transform='normalize'),
#        Real(low=0.001, high=0.1, prior='log-uniform', transform='normalize'),
#        Integer(low=2, high=128, prior='uniform', transform='normalize'),
#        Integer(low=1, high=100, prior='uniform', transform='normalize'),
#        Real(low=0.05, high=1.0, prior='uniform', transform='normalize'),
#        Real(low=0.15, high=1.0, prior='uniform', transform='normalize')]), 'base_estimator': GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), 'n_calls': 30, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'gp_hedge', 'acq_optimizer': 'auto', 'x0': None, 'y0': None, 'random_state': RandomState(MT19937) at 0x1ECABB47A40, 'verbose': True, 'callback': [<skopt.callbacks.CheckpointSaver object at 0x000001ECA8911D30>, <skopt.callbacks.VerboseCallback object at 0x000001ECA8A01760>], 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': -1, 'model_queue_size': None}, 'function': 'base_minimize'}
#             x: [753, 17, 0.022941144328643994, 59, 2, 0.9450916679006104, 0.6287949851687085]
#       x_iters: [[1215, 4, 0.036256176345762295, 77, 45, 0.14497617002710278, 0.5403615581709872], [567, 4, 0.020034427927560734, 9, 72, 0.9416250735649628, 0.15066195096486218], [1489, 13, 0.01672269700618368, 3, 3, 0.5485359272454697, 0.48988182595796725], [165, 20, 0.0029210748185657135, 13, 62, 0.41333889170380467, 0.9857462529357701], [753, 17, 0.022941144328643994, 59, 2, 0.9450916679006104, 0.6287949851687085], [640, 1, 0.002895927274708839, 32, 69, 0.62949682489349, 0.8582156749757399], [343, 8, 0.0023145798905204883, 97, 43, 0.24754457972477945, 0.6325452786469928], [144, 17, 0.007934293594590601, 52, 93, 0.7409083960635999, 0.42755965348496006], [899, 11, 0.08362652463906246, 108, 75, 0.5627075257696259, 0.648738490814271], [1451, 13, 0.0035644979070394624, 39, 17, 0.06485458640413425, 0.5098912586004143], [1500, 20, 0.0015839790436456772, 109, 100, 0.3080912274705716, 0.3049621543844617], [100, 13, 0.001, 32, 1, 0.05, 0.5424561201696069], [1500, 17, 0.006992341721255776, 128, 93, 0.4830908542567547, 1.0], [1500, 17, 0.01437979949854321, 67, 88, 1.0, 0.5915088632259466], [572, 17, 0.1, 24, 12, 1.0, 0.5612451612462592], [417, 8, 0.002048647014132568, 124, 22, 0.23287860697577578, 0.5125157499136633], [1459, 9, 0.001, 98, 23, 0.05, 0.22406354984908483], [1063, 8, 0.0011157837116082738, 127, 98, 0.09116268513049337, 0.318113647306532], [1500, 5, 0.050128928383632365, 128, 1, 0.05, 1.0], [1275, 20, 0.04323943063649066, 2, 100, 0.18777440435310172, 0.4922918066634896], [298, 13, 0.09430139273361374, 43, 100, 0.9645804610231924, 0.6526530460379836], [829, 4, 0.03201817955523996, 99, 97, 0.25955051608949153, 1.0], [100, 8, 0.0024735625371492794, 2, 1, 0.714722400827404, 0.6560868239983404], [100, 20, 0.09822214069416192, 5, 13, 0.9220548770045834, 0.45023360627073417], [100, 1, 0.013637676900103302, 74, 3, 0.17179711106168544, 0.262119974433357], [1500, 13, 0.019425618717147992, 74, 35, 0.2635250482474244, 0.9728248305081441], [1224, 17, 0.003923468774536708, 87, 87, 0.05, 0.1629942013362983], [1500, 13, 0.022807884678905585, 62, 93, 0.7703114587428822, 0.4003941954594421], [1500, 13, 0.0054566259766489315, 2, 87, 0.9084994568807491, 0.5937655912607597], [560, 13, 0.1, 127, 48, 0.7494738464552517, 0.7555484173420901]]

# %%
#result.x
# Out:
# [753, 17, 0.022941144328643994, 59, 2, 0.9450916679006104, 0.6287949851687085]

# %% [markdown]
# ## 8.2 Final Model

# %%
# best parameters
params = {'n_estimators' : 753,
            'max_depth' : 17,
            'learning_rate' : 0.02294,
            'num_leaves' : 59,
            'min_child_samples' : 2,
            'subsample' : 0.9450,
            'colsample_bytree' : 0.6287}


# LGBM Model
lgbm_model = LGBMClassifier(n_jobs=-1, random_state=42, subsample_freq=1)
lgbm_model.set_params(**params)
lgbm_model.fit(x_train, y_train)

# results of train dataset
y_pred = lgbm_model.predict_proba( x_val )
# Out:
# (0.33088345582720863, 0.7229626392833733)

# %%
# ------- check result--------

df8 = x_validation.copy()
df8['response'] = y_validation.copy()

# propensity score
df8['score'] = y_pred[:, 1].tolist()

# sort clients by propensity score
df8 = df8.sort_values( 'score', ascending=False )

# compute precision and recall at 20.000 k
metrics, data = precision_recall_at_k(df8)

# organize results
metrics = pd.DataFrame(metrics)
metrics = metrics.T
metrics['model_name'] = 'LGBM_Model'
metrics.columns = ['precision_at_K', 'recall_at_K', 'model_name']
metrics = metrics[['model_name', 'precision_at_K', 'recall_at_K']]
metrics
# Out:
#    model_name  precision_at_K  recall_at_K
# 0  LGBM_Model           0.331        0.723

# %%
data = gain_lift_curve(y_pred, y_val)

# %% [markdown]
# # 9.0 Tradução e interpretação do erro

# %% [markdown]
# ## 9.1 Bussiness Performance

# %% [markdown]
# ## 9.2 Total Performance

# %% [markdown]
# ## 9.3 Machine Learning Performance

# %% [markdown]
# # 10.0 Deploy model to production

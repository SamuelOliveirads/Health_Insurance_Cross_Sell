# %% [markdown]
# # 0.0 Imports

# %%
# Data manipulate
import numpy as np
import pandas as pd
import seaborn as sns
import psycopg2 as pg
import scikitplot as skplt
from pycorrcat import pycorrcat
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.gridspec import GridSpec

# Model Selection and Data preparation
from boruta import BorutaPy
from sklearn import preprocessing as pp
from sklearn import model_selection as ms

# ML and Metrics
from xgboost import XGBClassifier
from sklearn import ensemble as en
from sklearn import neighbors as nh
from lightgbm import LGBMClassifier
from imblearn import ensemble as ien
from sklearn import linear_model as lm
from imblearn.combine import SMOTETomek
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import balanced_accuracy_score

# Fine tunning
from skopt import gp_minimize
from skopt.space import Real, Integer
from skopt.utils import use_named_args
from skopt.callbacks import CheckpointSaver

# Others
import pickle
import warnings
from tabulate import tabulate
from IPython.display import Image
from numerize import numerize as nm
from credentials.credentialsdb import acess
# Out:
# f:\SamuelOliveiraAlvesd\Anaconda3\envs\Health_Insurance_Cross_Sell\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# ## 0.1 Helper Functions

# %%
def notebook_settings():
    '''Define configurations for notebook, matplotlib and Pandas.'''
    # %matplotlib inline
    plt.style.use('bmh')
    plt.rcParams['figure.figsize'] = [25,10]
    plt.rcParams['font.size'] = 24
    plt.rcParams['figure.dpi'] = 100
    
#    pd.options.display.max_columns = None
#    pd.options.display.max_rows = None
#    pd.set_option('display.expand_frame_repr', False)
    # configura o pandas para quantidade de casas decimeis
    pd.set_option('display.float_format', lambda x: '%.3f' % x)
    
    # ignora future warnings
    warnings.filterwarnings('ignore')
    
    sns.set()


def precision_recall_at_k( data, k=20000 ):
    '''
    Calculate metrics of precision and recall for an total number of rankings (k)
    return tuple of precision and recall, return dataframe with ranking
    '''
    # reset index
    data = data.reset_index( drop=True )

    # create ranking order
    data['ranking'] = data.index + 1 

    data['precision_at_k'] = data['response'].cumsum() / data['ranking']

    data['recall_at_k'] = data['response'].cumsum() / data['response'].sum()

    return ((data.loc[k, 'precision_at_k'], data.loc[k, 'recall_at_k']), data)


def gain_lift_curve(yhat, yval, plot = True, axvline='None'):
    '''
    plots gain and lift curve, respectively
    returns the curves and a table used to plot the curves
    '''

    # create table proba with the propensity score for each class (0 and 1)
    table_proba = pd.DataFrame(yhat)

    # add the 'response' column
    table_proba['response'] = yval.values

    # add the 'correct' column to evaluate wheter the prediction was right or not
    x = lambda x: "yes" if x[0] > x[1] and x['response'] == 0 else "yes" if x[1] > x[0] and x['response'] == 1 else "yes" if x[0] == x[1] else "no" 
    table_proba['correct'] = table_proba.apply(x, axis = 1)

    # order by propensity score for the class 1
    table_proba.sort_values(1, ascending = False, inplace = True)

    # create cumulative propensity score
    ## calculate the quantity of class 1 rows
    qty_class_1 = table_proba.groupby('response').count().loc[1,1]

    ## apply a score for every row which response is 1
    x = lambda x: 1/qty_class_1 if x['response'] == 1 else 0
    table_proba['propensity_score'] = table_proba.apply(x, axis = 1)
    table_proba['cumulative_propensity_score'] = np.cumsum(table_proba['propensity_score'])

    # create % cumulative of the base
    x = lambda x: 1/len(table_proba)
    table_proba['porc_base'] = table_proba.apply(x, axis = 1)
    table_proba['cumulative_porc_base'] = np.cumsum(table_proba['porc_base'])
    table_proba.drop('porc_base', axis = 1, inplace = True)

    # create the lift column
    table_proba['lift'] = table_proba['cumulative_propensity_score'] / table_proba['cumulative_porc_base']

    if plot:
        fig, axes = plt.subplots(2, 1, figsize=(8, 10))

        # gap between graphics
        fig.tight_layout(pad =5)

        # gain curve
        sns.lineplot(ax = axes[0], x = table_proba['cumulative_porc_base'], y = table_proba['cumulative_propensity_score'], label='cumulative (model)', linewidth = 2.5);
        sns.lineplot(ax = axes[0], x = table_proba['cumulative_porc_base'], y = table_proba['cumulative_porc_base'], label='baseline', linewidth = 2.5, color = 'black' )
        axes[0].lines[1].set_linestyle("--")
        axes[0].legend()
        axes[0].set_title('cumulative gains curve')
        axes[0].set_xlabel('percentage of sample')
        axes[0].set_ylabel('gain')

        if axvline != 'None':
            axes[0].axvline(axvline, 0, 1, color='green', ls='--', lw=2)

        # lift curve
        ## do not consider the beginning of the series, as it varies a lot (the sample is still small)
        table_proba_filtered = table_proba.query('cumulative_porc_base >= 0.1')

        sns.lineplot(ax = axes[1], x = table_proba_filtered['cumulative_porc_base'], y = table_proba_filtered['lift'], label='model', linewidth = 2.5 );
        sns.lineplot(ax = axes[1], x = table_proba_filtered['cumulative_porc_base'], y = np.ones(len(table_proba_filtered)), label='baseline', linewidth = 2.5, color = 'black' )
        axes[1].lines[1].set_linestyle("--")
        axes[1].legend()
        axes[1].set_title('lift curve')
        axes[1].set_xlabel('percentage of sample')

        if axvline != 'None':
            axes[1].axvline(axvline, 0, 1, color='green', ls='--', lw=2)
        
        plt.show();
        
    return (table_proba)


def runCrossValidation(model, x_train, y_train, n_splits, n_repeats=1, top_k = 20000, verbose=False):
    '''
    Make cross validation with parameters of total ranking (k)
    return a dataframe with metrics of precision and recall at k
    '''
    # local import
    from sklearn.metrics import balanced_accuracy_score
    from sklearn.model_selection import RepeatedStratifiedKFold

    
    if verbose:
        # the lenght_msg is to print only once a specific message
        length_msg = True
        i = 1

    
    # definition of the cross-validation strategy
    # - the "n_splits" parameter is the number of folds (k)
    # - the "n_repeats" parameter is the number of times cross-validator needs to 
    #   be repeated
    cv = RepeatedStratifiedKFold(n_splits = n_splits, n_repeats = n_repeats )
    
    precision_at_k = []
    recall_at_k = []
    b_accuracy_score = []

    x = x_train
    y = y_train
    
    for train_index, prim_val_index in cv.split(x, y):      
        x_training, x_prim_val = x.iloc[train_index], x.iloc[prim_val_index]
        y_training, y_prim_val = y.iloc[train_index], y.iloc[prim_val_index]
        
        if (verbose == True) and (length_msg == True):
            print(f'training_lenght:{x_training.shape[0]}\nvalidation_lenght:{x_prim_val.shape[0]}\n\n')
            length_msg = False
        
        if verbose:
            print(f'Iteration number:{i}')
            i += 1

        # fit and predict/predict_proba
        model.fit(x_training, y_training)
        yhat_proba = model.predict_proba(x_prim_val)
        yhat_prob = model.predict(x_prim_val)

        
        # get results
        table = gain_lift_curve(yhat_proba,y_prim_val, plot = False)
        metrics, new_table = precision_recall_at_k(table, top_k)
        ba_knn = balanced_accuracy_score(y_prim_val, yhat_prob)
        metrics = (*metrics, ba_knn)
        
        if verbose:
            print(metrics)
            print('')
        
        # save the metrics value to the list
        precision_at_k.append(metrics[0])
        recall_at_k.append(metrics[1])
        b_accuracy_score.append(metrics[2])
        
    df_results = pd.DataFrame([[np.mean(precision_at_k),np.std(precision_at_k)], 
                       [np.mean(recall_at_k), np.std(recall_at_k)], [np.mean(b_accuracy_score), np.std(b_accuracy_score)]], 
                      columns = ['mean', 'std'])
    
    df_results.index = ['precision_at_k', 'recall_at_k', 'accuracy_score']
    
    return(df_results)

# %%
notebook_settings()
# Out:
# <style>.container{width:100% !important; }</style>

# %% [markdown]
# ## 0.2 Load Data

# %%
# Credentials
host = acess.get('host')
port = acess.get('port')
database = acess.get('database')
username = acess.get('username')
password = acess.get('password')

# acess database
conn = pg.connect(user=username,
                  password = password,
                  host = host,
                  port = port,
                  database = database)

# make a cursor into database
cursor = conn.cursor()

# verify all schemas
query_schema = """
    SELECT nspname
    FROM pg_catalog.pg_namespace
    """

cursor.execute(query_schema)
record = cursor.fetchall()
record
# Out:
# [('pg_toast',),
#  ('pg_temp_1',),
#  ('pg_toast_temp_1',),
#  ('pg_catalog',),
#  ('information_schema',),
#  ('public',),
#  ('pa004',),
#  ('pg_temp_4',),
#  ('pg_toast_temp_4',),
#  ('pa005',),
#  ('pg_temp_9',),
#  ('pg_toast_temp_9',)]

# %%
# Verify tables from the schema
#query_tables = """
#    SELECT tablename
#    FROM pg_tables
#    WHERE schemaname='pa004'
#    """

#cursor.execute(query_tables)
#record = cursor.fetchall()
#record

# %%
# Collect tables into dataframe
query_tables_insurance = """
    SELECT *
    FROM pa004.users u INNER JOIN pa004.vehicle v ON (u.id = v.id)
                       INNER JOIN pa004.insurance i ON (u.id = i.id)
    """

df_raw = pd.read_sql(query_tables_insurance, conn)

# close connection into database
cursor.close()
conn.close()

# %% [markdown]
# # 1.0 Descrição dos dados

# %%
df1 = df_raw.copy()

# %%
# drop duplicates id columns
df1 = df1.loc[:, ~df1.columns.duplicated()].copy()
df1.head()
# Out:
#    id  gender  age  region_code  policy_sales_channel  driving_license  \
# 0   7    Male   23       11.000               152.000                1
# 1  13  Female   41       15.000                14.000                1
# 2  18  Female   25       35.000               152.000                1
# 3  31  Female   26        8.000               160.000                1
# 4  39    Male   45        8.000               124.000                1
#
#   vehicle_age vehicle_damage  previously_insured  annual_premium  vintage  \
# 0    < 1 Year            Yes                   0       23367.000      249
# 1    1-2 Year             No                   1       31409.000      221
# 2    < 1 Year             No                   1       46622.000      299
# 3    < 1 Year             No                   0        2630.000      136
# 4    1-2 Year            Yes                   0       42297.000      264
#
#    response
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# ## 1.2 Data Dimension

# %%
print(f'Number os rows: {df1.shape[0]}')
print(f'Number os cols: {df1.shape[1]}')
# Out:
# Number os rows: 381109
# Number os cols: 12

# %% [markdown]
# ## 1.3 Data Types

# %%
df1.dtypes
# Out:
# id                        int64
# gender                   object
# age                       int64
# region_code             float64
# policy_sales_channel    float64
# driving_license           int64
# vehicle_age              object
# vehicle_damage           object
# previously_insured        int64
# annual_premium          float64
# vintage                   int64
# response                  int64
# dtype: object

# %% [markdown]
# ## 1.4 Check NA

# %%
df1.isna().sum()
# Out:
# id                      0
# gender                  0
# age                     0
# region_code             0
# policy_sales_channel    0
# driving_license         0
# vehicle_age             0
# vehicle_damage          0
# previously_insured      0
# annual_premium          0
# vintage                 0
# response                0
# dtype: int64

# %% [markdown]
# ## 1.7 Descriptive Statistical

# %%
num_attributes = df1.select_dtypes(include=['int64', 'float64'])
cat_attributes = df1.select_dtypes(exclude=['int64', 'float64'])

# %% [markdown]
# ### 1.7.1 Numerical Attributes

# %%
# Central tendency and Dispersion
d1 = pd.DataFrame (num_attributes.apply( lambda x: x.max() - x.min() )).T
d2 = num_attributes.agg(['min', 'max', 'mean', 'median', 'std', 'skew', 'kurtosis'])

# concatenate
m2 = pd.concat([d1, d2]).T.reset_index()
m2.columns = ['attibutes', 'range', 'min', 'max', 'mean', 'median', 'std', 'skew', 'kurtosis']
m2 = m2[['attibutes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']]

m2
# Out:
#               attibutes      min        max      range       mean     median  \
# 0                    id    1.000 381109.000 381108.000 190555.000 190555.000
# 1                   age   20.000     85.000     65.000     38.823     36.000
# 2           region_code    0.000     52.000     52.000     26.389     28.000
# 3  policy_sales_channel    1.000    163.000    162.000    112.034    133.000
# 4       driving_license    0.000      1.000      1.000      0.998      1.000
# 5    previously_insured    0.000      1.000      1.000      0.458      0.000
# 6        annual_premium 2630.000 540165.000 537535.000  30564.390  31669.000
# 7               vintage   10.000    299.000    289.000    154.347    154.000
# 8              response    0.000      1.000      1.000      0.123      0.000
#
#          std    skew  kurtosis
# 0 110016.836  -0.000    -1.200
# 1     15.512   0.673    -0.566
# 2     13.230  -0.115    -0.868
# 3     54.204  -0.900    -0.971
# 4      0.046 -21.595   464.354
# 5      0.498   0.168    -1.972
# 6  17213.155   1.766    34.005
# 7     83.671   0.003    -1.201
# 8      0.328   2.302     3.299

# %% [markdown]
# ### 1.7.2 Categorical Attributes

# %%
cat_attributes.apply( lambda x: x.unique().shape[0])
# Out:
# gender            2
# vehicle_age       3
# vehicle_damage    2
# dtype: int64

# %%
plt.subplot (1, 3, 1)
sns.countplot(x='gender', data=df1)

plt.subplot (1, 3, 2)
sns.countplot(x='vehicle_age', data=df1)

plt.subplot (1, 3, 3)
sns.countplot(x='vehicle_damage', data=df1);

# %% [markdown]
# # 2.0 Feature Engineering

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1 MindMap Hypothesis

# %%
Image('F:/SamuelOliveiraAlvesd/Desktop/Data_Science/Projetos/Health_Insurance_Cross_Sell/reports/figures/Best_Customers_for_Car_Insurance.png')

# %% [markdown]
# ## 2.1.1 Hipóteses Veiculo

# %% [markdown]
# **1.** Pessoas que possuem carro mais caros possuem maior interesse em seguro
#
# **2.** Pessoas com carros de modelo popular possuem menos interesse em seguro
#
# **3.** Pessoas com carros comprados recentemente possuem maior interesse em seguro
#
# **4.** Pessoas que o carro já foi danificado possuem maior interesse em seguro em relação aos que não foram danificados

# %% [markdown]
# ## 2.1.2 Hipóteses Cliente

# %% [markdown]
# **1.** Pessoas com maiores salarios possuem mais interesse em seguros
#
# **2.** Pessoas mais velhas possuem maior interesse em seguro
#
# **3.** Pessoas com filhos possuem maior interesse em seguro
#
# **4.** Pessoas com familia possuem maior interesse em seguro

# %% [markdown]
# ## 2.1.3 Hipóteses Localização

# %% [markdown]
# **1.** Pessoas próximas de hospitais possuem mais interesse em seguro
#
# **2.** Pessoas em diferentes regiões possuem maior interesse em seguro

# %% [markdown]
# ## 2.1.4 Hipóteses Tempo

# %% [markdown]
# **1.** Pessoas com mais tempo com seguro tem maior interesse em outros seguros
#
# **2.** Pessoas possuem maior interesse em seguro no inverno.
#
# **3.** Pessoas possuem maior interesse em seguro nos dias de feriado
#
# **4.** Existe maior interesse em seguros com o passar dos anos.

# %% [markdown]
# ## 2.2 Lista final de hipóteses

# %% [markdown]
# **1.** Pessoas com carros comprados recentemente possuem maior interesse em seguro
#
# **2.** Pessoas que o carro já foi danificado possuem maior interesse em seguro
#
# **3.** Pessoas mais velhas possuem maior interesse em seguro
#
# **4.** Pessoas em melhores regiões possuem maior interesse em seguro
#
# **5.** Pessoas com mais tempo com seguro tem maior interesse em outros seguros

# %% [markdown]
# ## 2.3 Feature Engineering

# %%
# adjust format into vehicle age
df2['vehicle_age'] = df2['vehicle_age'].apply(lambda x: 'over_2_years' if x == '> 2 Years'
                                                        else 'between_1_2_year' if x == '1-2 Year'
                                                        else 'below_1_year')


# Convert categorical into numeric
df2['vehicle_damage'] = df2['vehicle_damage'].apply(lambda x: 1 if x=='Yes' else 0)

# %% [markdown]
# # 3.0 Filtragem de variáveis

# %%
df3 = df2.copy()

# %% [markdown]
# ## 3.1 Filtragem das linhas

# %%
# select only annual_premium bellow 65.000
df3 = df3[df3['annual_premium'] < 65000]

# %% [markdown]
# ## 3.2 Seleção das colunas

# %%
# Select only who has driving license
df3 = df3[df3['driving_license'] == 1]

# drop driving license column
df3.drop(columns='driving_license', inplace=True)

# %% [markdown]
# # 4.0 Análise exploratória dos dados

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1 Análise Univariada

# %% [markdown]
# ### 4.1.1 Response Variable

# %%
sns.countplot(x='response', data=df4);

# %% [markdown]
# ### 4.1.2 Numerical Variable

# %%
num_attributes = df4.select_dtypes(include='number')
num_attributes.hist(bins=25);

# %%
#policy_sales_channel
# count responses per channel
aux01 = df4[['policy_sales_channel', 'response']].groupby('policy_sales_channel').sum().reset_index() # count responses = 1 per channel
aux02 = df4[['policy_sales_channel', 'response']].groupby('policy_sales_channel').count().reset_index() # count total responses

# merge and make percentage
aux03 = pd.merge(aux01, aux02, how='inner', on='policy_sales_channel') # merge data of responses
aux03['response_y'] = aux03.apply(lambda x: int(x['response_y'] - x['response_x']), axis=1) # adjust total response for response = 0

# transform into percentage
aux03['response_x'] = aux03.apply(lambda x: x['response_x']/(x['response_x'] + x['response_y']) * 100, axis=1)
aux03['response_y'] = aux03.apply(lambda x: 100 - x['response_x'], axis=1)

# adjust columns name
aux03.columns = ['policy_sales_channel', 'response_yes', 'response_no']

# plot
aux03.plot(x = 'policy_sales_channel', kind = 'bar', stacked = True);

# %%
sns.boxplot(x='response', y='policy_sales_channel', data=df4);

# %%
# previously_insured
pd.crosstab(df4['previously_insured'], df4['response']).apply(lambda x : x / x.sum(), axis=1)
# Out:
# response               0     1
# previously_insured
# 0                  0.775 0.225
# 1                  0.999 0.001

# %% [markdown]
# ### 4.1.3 Categorical Variable

# %%
# gender
plt.subplot (1, 3, 1)
sns.countplot(x='gender', data=df4)

# vehicle_age
plt.subplot (1, 3, 2)
sns.countplot(x='vehicle_age', data=df4)

# vehicle_damage
plt.subplot (1, 3, 3)
sns.countplot(x='vehicle_damage', data=df4);

# %% [markdown]
# ## 4.2 Análise Bivariada

# %% [markdown]
# ### H1. Pessoas com carros comprados recentemente possuem maior interesse em seguro
# **FALSA** Pessoas com carros antigos possuem maior interesse em seguro

# %%
# plot for absolute response per vehicle age
plt.subplot(1, 2, 1)

aux01 = df4[['vehicle_age', 'response']].groupby('vehicle_age').sum().reset_index()
sns.barplot(x='vehicle_age', y='response', data=aux01);

# plot for percentages response per vehicle age
ax = plt.subplot(1, 2, 2)

aux02 = pd.crosstab(df4['vehicle_age'], df4['response']).apply(lambda x: x / x.sum(), axis=1).reset_index()
columns = ['vehicle_age', 'response_0', 'response_1']
aux02.columns = columns
aux02 = aux02[['vehicle_age', 'response_1', 'response_0']]

aux02.plot(x = 'vehicle_age', kind = 'bar', stacked = True, ax=ax);

# %% [markdown]
# ### H2. Pessoas que o carro já foi danificado possuem maior interesse em seguro em relação aos que não foram danificados
# **VERDADEIRA** Pessoas que tiveram o carro danificado demontram maior interesse em seguro, entretanto a maioria ainda não prefere.

# %%
aux1 = pd.crosstab(df4['vehicle_damage'], df4['response'])
aux1.apply(lambda x: x / x.sum(), axis=1)
# Out:
# response           0     1
# vehicle_damage
# 0              0.995 0.005
# 1              0.763 0.237

# %%
aux1.plot(kind='bar');

# %% [markdown]
# ### H3. Pessoas mais velhas possuem maior interesse em seguro
# **FALSO** Pessoas mais velhas possuem menor interesse em seguro a partir de 40 anos.

# %%
# ------------------ Absolute response per age --------------------------------
plt.subplot(2, 2, 1)
aux1 = df4[['age', 'response']].groupby('age').sum().reset_index()
sns.barplot(x='age', y='response', data=aux1)
plt.xticks(rotation=90)

# ------------------ Frequency response per age --------------------------------
# count responses per channel
aux01 = df4[['age', 'response']].groupby('age').sum().reset_index() # count responses = 1 per channel
aux02 = df4[['age', 'response']].groupby('age').count().reset_index() # count total responses

# merge and make percentage
aux03 = pd.merge(aux01, aux02, how='inner', on='age') # merge data of responses
aux03['response_y'] = aux03.apply(lambda x: int(x['response_y'] - x['response_x']), axis=1) # adjust total response for response = 0

# transform into percentage
aux03['response_x'] = aux03.apply(lambda x: x['response_x']/(x['response_x'] + x['response_y']) * 100, axis=1)
aux03['response_y'] = aux03.apply(lambda x: 100 - x['response_x'], axis=1)

# adjust columns name
aux03.columns = ['age', 'response_yes', 'response_no']
aux03.drop(columns=['response_no'], inplace=True)

# plot
ax = plt.subplot(2, 2, 2)
aux03.plot(x = 'age', kind = 'bar', ax=ax);


# --------- Boxplot --------------------------------
plt.subplot(2, 2, 3)
sns.boxplot(x='response', y='age', data=df4)

# ---------- Correlation ----------------------------
plt.subplot(2, 2, 4)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### H4. Pessoas em diferentes regiões possuem maior interesse em seguro
# **VERDADEIRA** Existem regiões com maiores interesse em seguro.

# %%
plt.subplot(1, 3, 1)
aux1 = df4[['region_code', 'response']].groupby('region_code').sum().reset_index()
aux2 = aux1[aux1['response'] < 4000]

sns.barplot(x='region_code', y='response', data=aux2)

plt.subplot(1, 3, 2)
sns.boxplot(x='response', y='region_code', data=df4)

plt.subplot(1, 3, 3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### H5. Pessoas com mais tempo com seguro tem maior interesse em outros seguros
# **FALSA** Pessoas com maior tempo de seguro são indiferentes das com menores tempos.

# %%
plt.subplot(1, 3, 1)
aux1 = df4[['vintage', 'response']].groupby('vintage').sum().sort_values('vintage').reset_index()
bins = list(np.arange(0, 310, 10))
aux1['vintage_binned'] = pd.cut(aux1['vintage'], bins = bins)

sns.barplot(x='vintage_binned', y='response', data=aux1)


plt.subplot(1, 3, 2)
sns.boxplot(x='response', y='vintage', data=df4)

plt.subplot(1, 3, 3)
sns.heatmap(aux1.corr(method='pearson'), annot=True);

# %% [markdown]
# ### 4.2.1 Resumo das Hipóteses

# %%
tab = [['Hipóteses', 'Conclusão', 'Relevância'],
       ['H1', 'Falsa', 'Baixa'],
       ['H2', 'Verdadeira', 'Médio'],
       ['H3', 'Falsa', 'Alto'],
       ['H4', 'Verdadeira', 'Baixa'],
       ['H5', 'Falsa', 'Baixa'],
      ]
print(tabulate(tab, headers='firstrow'))
# Out:
# Hipóteses    Conclusão    Relevância
# -----------  -----------  ------------
# H1           Falsa        Baixa
# H2           Verdadeira   Médio
# H3           Falsa        Alto
# H4           Verdadeira   Baixa
# H5           Falsa        Baixa

# %% [markdown]
# ## 4.3 Análise Multivariada

# %% [markdown]
# ### 4.3.1 Atributos numéricos

# %%
correlation = num_attributes.corr(method='pearson')
sns.heatmap(correlation, annot=True);

# %% [markdown]
# ### 4.3.2 Atributos categóricos

# %%
# only categorical data
a = df4.select_dtypes(include='object')

# Cramer V correlation
d = pycorrcat.corr_matrix(a, ['gender', 'vehicle_age'])
sns.heatmap(d, annot=True);

# %% [markdown]
# # 5.0 Preparação dos dados

# %%
X = df4.drop('response', axis=1)
y = df4['response'].copy()

# Split data into train and test
x_train, x_test, y_train, y_test = ms.train_test_split(X, y, test_size=0.20)

df5 = pd.concat([x_train, y_train], axis=1)

# %% [markdown]
# ## 5.1 Standardization

# %%
ss = pp.StandardScaler()

# annual_premium
df5['annual_premium'] = ss.fit_transform(df5[['annual_premium']].values)

# %%
# Before and after

aux01 = df4[df4['annual_premium'] > 10000]
f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(25, 5))
sns.histplot(x='annual_premium', data=aux01, bins=40, ax=ax1);

aux01 = df5[df5['annual_premium'] >= -1]
sns.histplot(x='annual_premium', data=aux01, bins=40, ax=ax2);
f.suptitle('Before and after Standardization');

# %% [markdown]
# ## 5.2 Rescaling

# %%
# Check outliers
f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(25, 5))
sns.boxplot(x='age', data=df4, ax=ax1);

sns.boxplot(x='vintage', data=df4, ax=ax2);

# %%
mms_age = pp.MinMaxScaler()
mms_vintage = pp.MinMaxScaler()

# Age
df5['age'] = mms_age.fit_transform(df5[['age']].values)

# Vintage
df5['vintage'] = mms_vintage.fit_transform(df5[['vintage']].values)

# %%
# -----------Before and after scaler-------------------

# plots for age
f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(25, 4))
sns.histplot(x='age', data=df4, bins=40, ax=ax1);

sns.histplot(x='age', data=df5, bins=40, ax=ax2);
f.suptitle('Before and after Scaler (Age)');

# plots for vintage
f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(25, 4))
sns.histplot(x='vintage', data=df4, bins=40, ax=ax1);

sns.histplot(x='vintage', data=df5, bins=40, ax=ax2);
f.suptitle('Before and after Scaler (Vintage)');

# %% [markdown]
# ## 5.3 Transformação

# %% [markdown]
# ### 5.3.1 Encoding

# %%
# gender - Target Encoding
target_encode_gender = df5.groupby('gender')['response'].mean()
df5.loc[:, 'gender'] = df5['gender'].map(target_encode_gender)

# region_code - Target Encoding
target_encode_region_code = df5.groupby('region_code')['response'].mean()
df5.loc[:, 'region_code'] = df5['region_code'].map(target_encode_region_code)

# vehicle_age - One Hot Encoding
df5 = pd.get_dummies(df5, prefix='vehicle_age', columns=['vehicle_age'])

# policy_sales_channel - Frequency Encoding
fe_policy_sales_channel = df5.groupby('policy_sales_channel').size() / len(df5)
df5.loc[:, 'policy_sales_channel'] = df5['policy_sales_channel'].map(fe_policy_sales_channel)

# %% [markdown]
# ## 5.4 Target variable resample

# %%
# Before resample
df5['response'].value_counts()
# Out:
# 0    261512
# 1     36435
# Name: response, dtype: int64

# %%
x_train_res, y_train_res = SMOTETomek(random_state=42).fit_resample(df5.drop(columns=['response'], axis=1), df5['response'])

# After resample
y_train_res.value_counts()
# Out:
# 0    232869
# 1    232869
# Name: response, dtype: int64

# %% [markdown]
# ## 5.5 Test data preparation

# %%
# annual_premium
x_test.loc[:, 'annual_premium'] = ss.transform(x_test[['annual_premium']].values)

# Age
x_test.loc[:, 'age'] = mms_age.transform(x_test[['age']].values)

# Vintage
x_test.loc[:, 'vintage'] = mms_vintage.transform(x_test[['vintage']].values)

# gender - Target Encoding
x_test.loc[:, 'gender'] = x_test.loc[:, 'gender'].map(target_encode_gender)

# region_code - Target Encoding
x_test.loc[:, 'region_code'] = x_test.loc[:, 'region_code'].map(target_encode_region_code)

# vehicle_age - One Hot Encoding
x_test = pd.get_dummies(x_test, prefix='vehicle_age', columns=['vehicle_age'])

# policy_sales_channel - Frequency Encoding
x_test.loc[:, 'policy_sales_channel'] = x_test.loc[:, 'policy_sales_channel'].map(fe_policy_sales_channel)

# fillna
x_test = x_test.fillna(0)

# %% [markdown]
# # 6.0 Feature Selection

# %% [markdown]
# ## 6.1 feature selection per importance

# %%
# model definition
#forest = en.ExtraTreesClassifier(n_estimators=250, random_state=0, n_jobs=-1)

# data preparation
#x_train_f = x_train_res.drop(['id'], axis=1)
#y_train_f = y_train_res.values
#forest.fit(x_train_f, y_train_f)

# saving model
#pickle.dump(forest, open('F:/SamuelOliveiraAlvesd/Desktop/Data_Science/Projetos/Health_Insurance_Cross_Sell/models/extra_tree_selector.pkl', 'wb'))

# loading model selector
#file = open('F:/SamuelOliveiraAlvesd/Desktop/Data_Science/Projetos/Health_Insurance_Cross_Sell/models/extra_tree_selector.pkl','rb')
#forest = pickle.load(file)
#file.close()

# %%
# Collect features from model selector
#importances = forest.feature_importances_
#std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
#indices = np.argsort(importances)[::-1]

# Organize and print ranking per features
#print('Feature ranking:')
#df = pd.DataFrame()
#for i, j in zip(x_train_f, forest.feature_importances_):
#    aux = pd.DataFrame({'feature': i, 'importance': j}, index=[0])
#    df = pd.concat([df, aux], axis=0)

#print(df.sort_values('importance', ascending=False))

# plot the impurity-based feature importances of the forest
#plt.figure()
#plt.title('Feature importances')
#plt.bar(range(x_train_f.shape[1]), importances[indices], color='r', yerr=std[indices], align='center')
#plt.xticks(range(x_train_f.shape[1]), indices)
#plt.xlim([-1, x_train_f.shape[1]])
#plt.show()

# %% [markdown]
# ## 6.2 Boruta selection

# %%
# training and test dataset for Boruta
#x_train_f = x_train_f.values
#y_train_f = y_train_f.ravel()

# define RandomForestRegressor
#rf = RandomForestRegressor(n_jobs=-1)

# define Boruta
#boruta = BorutaPy(rf, n_estimators='auto', verbose=2, random_state=42).fit(x_train_f, y_train_f)

#cols_selected = boruta.support_.tolist()

# best features
#cols_selected_boruta = x_train_f.iloc[:, cols_selected]

# not selected boruta
#cols_not_selected_boruta = list(np.setdiff1d(x_train_f.columns, cols_selected_boruta.columns))

# %%
#cols_not_selected_boruta

# %%
#cols_selected_boruta.columns

# %% [markdown]
# # 7.0 Machine Learning Modeling

# %%
# select features from Metrics
cols_selected = ['id', 'vintage', 'annual_premium', 'age', 'region_code',
                'vehicle_damage', 'policy_sales_channel', 'previously_insured']


# Dataframe for metrics
x_testm = x_test[cols_selected].copy()
y_testm = y_test.copy()

# select features from ML
cols_selected = ['vintage', 'annual_premium', 'age', 'region_code',
                'vehicle_damage', 'policy_sales_channel', 'previously_insured']

# Dataframe for ML
x_train_res = x_train_res[cols_selected]
x_test = x_test[cols_selected]

# %% [markdown]
# ## 7.1 K-Nearest Neighbors

# %%
# model definition
knn_model = nh.KNeighborsClassifier(n_neighbors=7)

# model training
knn_model.fit(x_train_res, y_train_res)

# model prediction - Generalization
yhat_knn = knn_model.predict_proba(x_test)
yhatp_knn = knn_model.predict( x_test )


# ---------- Metrics ------------------
# Accuracy score
ba_knn = balanced_accuracy_score(y_test, yhatp_knn)

print(f'Accuracy from balanced score is: {ba_knn:.3f}')
# Out:
# Accuracy from balanced score is: 0.722

# %%
# Accumulative gain
skplt.metrics.plot_cumulative_gain(y_test, yhat_knn);

# %% [markdown]
# ### 7.1.1 K-Nearest Neighbors - Cross-Validation

# %%
# making cross validation
#cv_knn = runCrossValidation(knn_model, x_train_res, y_train_res, n_splits=10, top_k = 20000, verbose=True)

# saving results
#pickle.dump(cv_knn, open('../data/processed/cv_knn.pkl', 'wb'))

# loading results
file = open('../data/processed/cv_knn.pkl','rb')
cv_knn = pickle.load(file)
file.close()

cv_knn
# Out:
#                 mean   std
# precision_at_k 0.872 0.011
# recall_at_k    0.749 0.010
# accuracy_score 0.847 0.002

# %% [markdown]
# ## 7.2 Logistic Regression

# %%
# model definition
lr_model = lm.LogisticRegression( random_state=42 ) 

# model training
lr_model.fit( x_train_res, y_train_res )

# model prediction
yhat_lr = lr_model.predict_proba( x_test )
yhatp_lr = lr_model.predict( x_test )


# ---------- Metrics ------------------
# Accuracy score
ba_lr = balanced_accuracy_score(y_test, yhatp_lr)

print(f'Accuracy from balanced score is: {ba_lr:.3f}')
# Out:
# Accuracy from balanced score is: 0.785

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain( y_test, yhat_lr );

# %% [markdown]
# ### 7.2.1 Logistic Regression - Cross-Validation

# %%
# making cross validation
#cv_lr = runCrossValidation(lr_model, x_train_res, y_train_res, n_splits=10, top_k = 20000, verbose=True)

# saving results
#pickle.dump(cv_lr, open('../data/processed/cv_lr.pkl', 'wb'))

# loading results
file = open('../data/processed/cv_lr.pkl','rb')
cv_lr = pickle.load(file)
file.close()

cv_lr
# Out:
#                 mean   std
# precision_at_k 0.775 0.001
# recall_at_k    0.665 0.001
# accuracy_score 0.796 0.001

# %% [markdown]
# ## 7.3 Extra Trees

# %%
# model definition
#et_model = en.ExtraTreesClassifier(n_estimators=1000, n_jobs=-1, random_state=42) 

# model training
#et_model.fit( x_train_res, y_train_res )

# model prediction
#yhat_et = et_model.predict_proba( x_test )
#yhatp_et = et_model.predict( x_test )

# ---------- Metrics ------------------
# Accuracy score
#ba_et = balanced_accuracy_score(y_test, yhatp_et)

# Accumulative gain plot
#plot_et = skplt.metrics.plot_cumulative_gain( y_test, yhat_et);

# -------------- Saving and Loading Metrics -------------------
# saving results
#pickle.dump(ba_et, open('../data/interim/ba_et.pkl', 'wb'))
#pickle.dump(plot_et, open('../data/interim/plot_et.pkl', 'wb'))

# loading results
file = open('../data/interim/ba_et.pkl','rb')
ba_et = pickle.load(file)
file.close()

# show metrics
print(f'Accuracy from balanced score is: {ba_et:.3f}')

# %%
# loading results
file = open('../data/interim/plot_et.pkl','rb')
plot_et = pickle.load(file)
file.close()

# Accumulative Gain
plot_et;

# %% [markdown]
# ### 7.3.1 Extra Trees - Cross-Validation

# %%
# making cross validation
#cv_et = runCrossValidation(et_model, x_train_res, y_train_res, n_splits=10, top_k = 20000, verbose=True)

# saving results
#pickle.dump(cv_et, open('../data/processed/cv_et.pkl', 'wb'))

# loading results
file = open('../data/processed/cv_et.pkl','rb')
cv_et = pickle.load(file)
file.close()

cv_et
# Out:
#                 mean   std
# precision_at_k 0.965 0.001
# recall_at_k    0.829 0.001
# accuracy_score 0.904 0.001

# %% [markdown]
# ## 7.4 XGBoost

# %%
# model definition
#xgb_model = XGBClassifier(n_estimators=1000, n_jobs=-1, random_state=42)

# model training
#xgb_model.fit( x_train_res, y_train_res )

# model prediction
#yhat_xgb = xgb_model.predict_proba( x_test )
#yhatp_xgb = xgb_model.predict( x_test )

# ---------- Metrics ------------------
# Accuracy score
#ba_xgb = balanced_accuracy_score(y_test, yhatp_xgb)

# Accumulative gain plot
#plot_xbg = skplt.metrics.plot_cumulative_gain( y_test, yhat_xgb );


# -------------- Saving and Loading model -------------------
# saving results
#pickle.dump(ba_xgb, open('../data/interim/ba_xgb.pkl', 'wb'))
#pickle.dump(plot_xbg, open('../data/interim/plot_xbg.pkl', 'wb'))

# loading results
file = open('../data/interim/ba_xgb.pkl','rb')
ba_xgb = pickle.load(file)
file.close()

# show metrics
print(f'Accuracy from balanced score is: {ba_xgb:.3f}')
# Out:
# Accuracy from balanced score is: 0.564

# %%
# loading results
file = open('../data/interim/plot_xbg.pkl','rb')
plot_xbg = pickle.load(file)
file.close()

# ---------- Metrics ------------------
# Accumulative Gain
plot_xbg;

# %% [markdown]
# ### 7.4.1 XGBoost - Cross-Validation

# %%
#xgb_model = XGBClassifier(n_estimators=1000, n_jobs=-1, random_state=42)

# making cross validation
#cv_xgb = runCrossValidation(xgb_model, x_train_res, y_train_res, n_splits=10, top_k = 20000, verbose=True)

# saving results
#pickle.dump(cv_xgb, open('../data/processed/cv_xgb.pkl', 'wb'))

# loading results
file = open('../data/processed/cv_xgb.pkl','rb')
cv_xgb = pickle.load(file)
file.close()

cv_xgb
# Out:
#                 mean   std
# precision_at_k 0.995 0.001
# recall_at_k    0.854 0.001
# accuracy_score 0.921 0.001

# %% [markdown]
# ## 7.5 LGBM

# %%
# model definition
lgbm_model = LGBMClassifier(n_estimators=1000, n_jobs=-1, random_state=42)

# model training
lgbm_model.fit( x_train_res, y_train_res )

# model prediction
yhat_lgbm = lgbm_model.predict_proba( x_test )
yhatp_lgbm = lgbm_model.predict( x_test )


# ---------- Metrics ------------------
# Accuracy score
ba_lgbm = balanced_accuracy_score(y_test, yhatp_lgbm)

print(f'Accuracy from balanced score is: {ba_lgbm:.3f}')
# Out:
# Accuracy from balanced score is: 0.551

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain( y_test, yhat_lgbm );

# %% [markdown]
# ### 7.5.1 LGBM - Cross-Validation

# %%
# making cross validation
#cv_lgbm = runCrossValidation(lgbm_model, x_train_res, y_train_res, n_splits=10, top_k=20000, verbose=True)

# saving results
#pickle.dump(cv_lgbm, open('../data/processed/cv_lgbm.pkl', 'wb'))

# loading results
file = open('../data/processed/cv_lgbm.pkl','rb')
cv_lgbm = pickle.load(file)
file.close()

cv_lgbm
# Out:
#                 mean   std
# precision_at_k 0.991 0.001
# recall_at_k    0.851 0.001
# accuracy_score 0.921 0.001

# %% [markdown]
# ## 7.6 Balanced Random Forest Classifier

# %%
# model definition
#brf_model = ien.BalancedRandomForestClassifier(n_estimators=1000, n_jobs=-1, random_state=42, sampling_strategy=0.14)

# model training - with unbalanced data
#brf_model.fit( x_train, y_train )

# model prediction
#yhat_brf = brf_model.predict_proba( x_test )
#yhatp_brf = brf_model.predict( x_test )

# ---------- Metrics ------------------
# Accuracy score
#ba_brf = balanced_accuracy_score(y_test, yhatp_brf)

# Accumulative gain plot
#plot_brf = skplt.metrics.plot_cumulative_gain( y_test, yhat_brf )


# -------------- Saving and Loading model -------------------
# saving results
#pickle.dump(ba_brf, open('../data/interim/ba_brf.pkl', 'wb'))
#pickle.dump(plot_brf, open('../data/interim/plot_brf.pkl', 'wb'))

# loading results
file = open('../data/interim/ba_brf.pkl','rb')
ba_brf = pickle.load(file)
file.close()

# show metrics
print(f'Accuracy from balanced score is: {ba_brf:.3f}')
# Out:
# Accuracy from balanced score is: 0.546

# %%
# loading results
file = open('../data/interim/plot_brf.pkl','rb')
table_brf = pickle.load(file)
file.close()

# ---------- Metrics ------------------
# Accumulative Gain
table_brf;

# %% [markdown]
# ### 7.6.1 Balanced Random Forest - Cross-Validation

# %%
# making cross validation
#cv_brf = runCrossValidation(brf_model, x_train, x_test, y_train, y_test, n_splits=10, n_repeats=2, top_k=20000, verbose=True)

# saving results
#pickle.dump(cv_brf, open('../data/processed/cv_brf.pkl', 'wb'))

# loading results
file = open('../data/processed/cv_brf.pkl','rb')
cv_brf = pickle.load(file)
file.close()

cv_brf
# Out:
#                 mean   std
# precision_at_k 0.973 0.002
# recall_at_k    0.803 0.001

# %% [markdown]
# ## 7.7 Compare Model's Performance

# %% [markdown]
# ### 7.7.1 Real Performance - Cross Validation

# %%
#final_cv = pd.DataFrame()
#model_list = {'KNN_model' : cv_knn, 'Logistic_Regression' : cv_lr, 'Extra_Trees_Classifier' : cv_et, 'XGBoost' : cv_xgb, 'LGBM' : cv_lgbm, 'Balanced_RF' : cv_brf}

#for n, m in model_list.items():
#    m[n] = m.apply(lambda x : (str(x['mean']))[:5] + '+/-' + (str(x['std']))[:5], axis=1)
#    m = m[[n]].T
#    m.reset_index(inplace=True)
#    if len(m.columns) > 3:
#        m.drop(columns=['accuracy_score'], inplace=True)
#    m.columns = ['model_name', 'precision_at_k', 'recall_at_k']

#    final_cv = pd.concat([final_cv, m])

#final_cv.sort_values('precision_at_k', ascending=False, inplace=True)

# saving results
#pickle.dump(final_cv, open('../data/processed/ml_result_cv.pkl', 'wb'))

# loading results
file = open('../data/processed/ml_result_cv.pkl','rb')
ml_result_cv = pickle.load(file)
file.close()
ml_result_cv
# Out:
#                model_name precision_at_k    recall_at_k
# 0                 XGBoost  0.994+/-0.001  0.854+/-0.001
# 0                    LGBM  0.990+/-0.001  0.850+/-0.001
# 0             Balanced_RF  0.972+/-0.001  0.802+/-0.001
# 0  Extra_Trees_Classifier  0.964+/-0.001  0.828+/-0.001
# 0               KNN_model  0.871+/-0.011  0.748+/-0.009
# 0     Logistic_Regression  0.774+/-0.001  0.665+/-0.001

# %% [markdown]
# # 8.0 Hyper Parameter Fine Tunning

# %% [markdown]
# ## 8.1 Bayesian Search

# %%
""" # model definition
lgbm_model = LGBMClassifier(n_jobs=-1, random_state=42, subsample_freq=1)


# Search space for hyper parameters
search_space = [Integer( 100, 1500, name = 'n_estimators'), 
                Integer(1, 20, name = 'max_depth'), 
                Real(0.001, 0.1, 'log-uniform', name = 'learning_rate'),
                Integer(2, 128, name = 'num_leaves'),
                Integer(1, 100, name = 'min_child_samples'),
                Real(0.05, 1.0, name = 'subsample'),
                Real(0.15, 1.0, name = 'colsample_bytree')]



# applying cross-validation into tunning
@use_named_args(search_space)
def model_eval( **params ):
	
    lgbm_model.set_params(**params)
    print(lgbm_model)
    ft_result = runCrossValidation(lgbm_model, x_train_res, y_train_res, n_splits=10, top_k=20000, verbose=False)
    return -ft_result['mean'][0]


# create checkpoints
checkpoint_callback = CheckpointSaver('../models/lgbm_ft.pkl')

# return results and run bayesian optimize
result = gp_minimize( model_eval, search_space, n_calls = 50, 
                      n_initial_points = 10, verbose=True, n_jobs=-1, 
                      random_state= 42, callback=[checkpoint_callback])
result """
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.5403615581709872,
#                learning_rate=0.036256176345762295, max_depth=4,
#                min_child_samples=45, n_estimators=1215, num_leaves=77,
#                random_state=42, subsample=0.14497617002710278,
#                subsample_freq=1)
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 139.8021
# Function value obtained: -0.9899
# Current minimum: -0.9899
# Iteration No: 2 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.15066195096486218,
#                learning_rate=0.020034427927560734, max_depth=4,
#                min_child_samples=72, n_estimators=567, num_leaves=9,
#                random_state=42, subsample=0.9416250735649628, subsample_freq=1)
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 76.7432
# Function value obtained: -0.9517
# Current minimum: -0.9899
# Iteration No: 3 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.48988182595796725,
#                learning_rate=0.01672269700618368, max_depth=13,
#                min_child_samples=3, n_estimators=1489, num_leaves=3,
#                random_state=42, subsample=0.5485359272454697, subsample_freq=1)
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 149.2972
# Function value obtained: -0.9466
# Current minimum: -0.9899
# Iteration No: 4 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.9857462529357701,
#                learning_rate=0.0029210748185657135, max_depth=20,
#                min_child_samples=62, n_estimators=165, num_leaves=13,
#                random_state=42, subsample=0.41333889170380467,
#                subsample_freq=1)
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 44.3852
# Function value obtained: -0.9193
# Current minimum: -0.9899
# Iteration No: 5 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.6287949851687085,
#                learning_rate=0.022941144328643994, max_depth=17,
#                min_child_samples=2, n_estimators=753, num_leaves=59,
#                random_state=42, subsample=0.9450916679006104, subsample_freq=1)
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 158.2223
# Function value obtained: -0.9921
# Current minimum: -0.9921
# Iteration No: 6 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.8582156749757399,
#                learning_rate=0.002895927274708839, max_depth=1,
#                min_child_samples=69, n_estimators=640, num_leaves=32,
#                random_state=42, subsample=0.62949682489349, subsample_freq=1)
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 75.9506
# Function value obtained: -0.8517
# Current minimum: -0.9921
# Iteration No: 7 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.6325452786469928,
#                learning_rate=0.0023145798905204883, max_depth=8,
#                min_child_samples=43, n_estimators=343, num_leaves=97,
#                random_state=42, subsample=0.24754457972477945,
#                subsample_freq=1)
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 83.1519
# Function value obtained: -0.9565
# Current minimum: -0.9921
# Iteration No: 8 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.42755965348496006,
#                learning_rate=0.007934293594590601, max_depth=17,
#                min_child_samples=93, n_estimators=144, num_leaves=52,
#                random_state=42, subsample=0.7409083960635999, subsample_freq=1)
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 46.4130
# Function value obtained: -0.9780
# Current minimum: -0.9921
# Iteration No: 9 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.648738490814271,
#                learning_rate=0.08362652463906246, max_depth=11,
#                min_child_samples=75, n_estimators=899, num_leaves=108,
#                random_state=42, subsample=0.5627075257696259, subsample_freq=1)
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 212.0447
# Function value obtained: -0.9922
# Current minimum: -0.9922
# Iteration No: 10 started. Evaluating function at random point.
# LGBMClassifier(colsample_bytree=0.5098912586004143,
#                learning_rate=0.0035644979070394624, max_depth=13,
#                min_child_samples=17, n_estimators=1451, num_leaves=39,
#                random_state=42, subsample=0.06485458640413425,
#                subsample_freq=1)
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 264.6507
# Function value obtained: -0.9808
# Current minimum: -0.9922
# Iteration No: 11 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.5030495959432745, max_depth=20,
#                min_child_samples=29, n_estimators=993, num_leaves=128,
#                random_state=42, subsample=0.06966321655840604,
#                subsample_freq=1)
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 218.2704
# Function value obtained: -0.7944
# Current minimum: -0.9922
# Iteration No: 12 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.6661666610160389, max_depth=17,
#                min_child_samples=12, n_estimators=1450, num_leaves=128,
#                random_state=42, subsample=0.21919697706191216,
#                subsample_freq=1)
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 279.5004
# Function value obtained: -0.8378
# Current minimum: -0.9922
# Iteration No: 13 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.7377877973043283, max_depth=10,
#                min_child_samples=77, n_estimators=131, num_leaves=57,
#                random_state=42, subsample=0.5513188940159042, subsample_freq=1)
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 46.8792
# Function value obtained: -0.9915
# Current minimum: -0.9922
# Iteration No: 14 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.9012002936834459, max_depth=12,
#                min_child_samples=15, n_estimators=323, num_leaves=121,
#                random_state=42, subsample=0.8699800765203968, subsample_freq=1)
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 78.4062
# Function value obtained: -0.9920
# Current minimum: -0.9922
# Iteration No: 15 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.9245595354691893, learning_rate=0.001,
#                max_depth=20, min_child_samples=54, n_estimators=687,
#                num_leaves=125, random_state=42, subsample_freq=1)
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 189.9446
# Function value obtained: -0.9727
# Current minimum: -0.9922
# Iteration No: 16 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.3625912236164674,
#                learning_rate=0.006871855124236871, max_depth=2,
#                min_child_samples=2, n_estimators=911, num_leaves=61,
#                random_state=42, subsample=0.05, subsample_freq=1)
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 88.0393
# Function value obtained: -0.9202
# Current minimum: -0.9922
# Iteration No: 17 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.3157779998862144,
#                learning_rate=0.0024469515641850565, max_depth=13,
#                min_child_samples=90, n_estimators=753, num_leaves=128,
#                random_state=42, subsample_freq=1)
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 163.5565
# Function value obtained: -0.9557
# Current minimum: -0.9922
# Iteration No: 18 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.8346026835841351, max_depth=6,
#                min_child_samples=27, n_estimators=1244, num_leaves=128,
#                random_state=42, subsample=0.4912856722761596, subsample_freq=1)
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 249.7125
# Function value obtained: -0.9924
# Current minimum: -0.9924
# Iteration No: 19 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.3723285664428486,
#                learning_rate=0.026258313312433123, max_depth=16,
#                min_child_samples=100, n_estimators=844, num_leaves=128,
#                random_state=42, subsample_freq=1)
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 169.9621
# Function value obtained: -0.9928
# Current minimum: -0.9928
# Iteration No: 20 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.15, learning_rate=0.008959422875679027,
#                max_depth=18, min_child_samples=100, num_leaves=128,
#                random_state=42, subsample_freq=1)
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 36.9916
# Function value obtained: -0.9819
# Current minimum: -0.9928
# Iteration No: 21 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.5409240396822818,
#                learning_rate=0.09453787327259737, max_depth=4,
#                min_child_samples=100, n_estimators=1500, num_leaves=128,
#                random_state=42, subsample=0.1958903538182859, subsample_freq=1)
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 183.2960
# Function value obtained: -0.9921
# Current minimum: -0.9928
# Iteration No: 22 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.8661207955631381,
#                learning_rate=0.041601335130940525, max_depth=7,
#                min_child_samples=72, n_estimators=1462, num_leaves=102,
#                random_state=42, subsample=0.05, subsample_freq=1)
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 230.8759
# Function value obtained: -0.9897
# Current minimum: -0.9928
# Iteration No: 23 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.15, learning_rate=0.001, max_depth=12,
#                min_child_samples=100, n_estimators=761, num_leaves=128,
#                random_state=42, subsample=0.05, subsample_freq=1)
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 132.3285
# Function value obtained: -0.9723
# Current minimum: -0.9928
# Iteration No: 24 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.24777640469546414, max_depth=9,
#                min_child_samples=100, n_estimators=1500, num_leaves=128,
#                random_state=42, subsample=0.7172056197226296, subsample_freq=1)
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 306.2892
# Function value obtained: -0.9857
# Current minimum: -0.9928
# Iteration No: 25 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.9917714819178709, max_depth=18,
#                min_child_samples=59, n_estimators=1132, num_leaves=50,
#                random_state=42, subsample_freq=1)
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 143.8686
# Function value obtained: -0.9921
# Current minimum: -0.9928
# Iteration No: 26 started. Searching for the next optimal point.
# LGBMClassifier(max_depth=1, min_child_samples=84, n_estimators=188,
#                num_leaves=128, random_state=42, subsample_freq=1)
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 34.0182
# Function value obtained: -0.9134
# Current minimum: -0.9928
# Iteration No: 27 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.15, learning_rate=0.03945487533160144,
#                max_depth=7, min_child_samples=82, n_estimators=1500,
#                num_leaves=90, random_state=42, subsample=0.31156036945715576,
#                subsample_freq=1)
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 241.1285
# Function value obtained: -0.9919
# Current minimum: -0.9928
# Iteration No: 28 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.15791525716686064, max_depth=10,
#                min_child_samples=36, n_estimators=1484, num_leaves=51,
#                random_state=42, subsample=0.05, subsample_freq=1)
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 201.4867
# Function value obtained: -0.9925
# Current minimum: -0.9928
# Iteration No: 29 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.30934758783654365, learning_rate=0.001,
#                max_depth=8, min_child_samples=1, n_estimators=1500,
#                num_leaves=98, random_state=42, subsample_freq=1)
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 258.8440
# Function value obtained: -0.9390
# Current minimum: -0.9928
# Iteration No: 30 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.3598061381279266,
#                learning_rate=0.0840056445152498, max_depth=5,
#                min_child_samples=1, n_estimators=107, num_leaves=39,
#                random_state=42, subsample=0.14556129033486065,
#                subsample_freq=1)
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 28.9557
# Function value obtained: -0.9707
# Current minimum: -0.9928
# Iteration No: 31 started. Searching for the next optimal point.
# LGBMClassifier(max_depth=16, min_child_samples=1, num_leaves=2, random_state=42,
#                subsample_freq=1)
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 23.7895
# Function value obtained: -0.8832
# Current minimum: -0.9928
# Iteration No: 32 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.1838182704709469, max_depth=20,
#                min_child_samples=100, n_estimators=1500, num_leaves=90,
#                random_state=42, subsample_freq=1)
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 249.1684
# Function value obtained: -0.9926
# Current minimum: -0.9928
# Iteration No: 33 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.9138550161303558, max_depth=17,
#                min_child_samples=100, n_estimators=1500, num_leaves=76,
#                random_state=42, subsample_freq=1)
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 238.5774
# Function value obtained: -0.9917
# Current minimum: -0.9928
# Iteration No: 34 started. Searching for the next optimal point.
# LGBMClassifier(learning_rate=0.001, max_depth=20, min_child_samples=57,
#                n_estimators=1500, num_leaves=72, random_state=42,
#                subsample_freq=1)
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 342.2089
# Function value obtained: -0.9662
# Current minimum: -0.9928
# Iteration No: 35 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.561651824315158, max_depth=4,
#                min_child_samples=22, n_estimators=544, num_leaves=88,
#                random_state=42, subsample=0.05, subsample_freq=1)
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 65.0687
# Function value obtained: -0.9862
# Current minimum: -0.9928
# Iteration No: 36 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.15, learning_rate=0.051216405326953415,
#                max_depth=15, min_child_samples=100, n_estimators=605,
#                num_leaves=110, random_state=42, subsample_freq=1)
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 98.1648
# Function value obtained: -0.9921
# Current minimum: -0.9928
# Iteration No: 37 started. Searching for the next optimal point.
# LGBMClassifier(learning_rate=0.04830404437848275, max_depth=8,
#                min_child_samples=29, n_estimators=1500, num_leaves=67,
#                random_state=42, subsample=0.12059109103353524,
#                subsample_freq=1)
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 244.3688
# Function value obtained: -0.9917
# Current minimum: -0.9928
# Iteration No: 38 started. Searching for the next optimal point.
# LGBMClassifier(max_depth=10, min_child_samples=1, n_estimators=1500,
#                num_leaves=93, random_state=42, subsample=0.6708115536972049,
#                subsample_freq=1)
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 297.1091
# Function value obtained: -0.9745
# Current minimum: -0.9928
# Iteration No: 39 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.15, learning_rate=0.071203188922792,
#                max_depth=11, min_child_samples=100, n_estimators=520,
#                num_leaves=45, random_state=42, subsample=0.32304875857647053,
#                subsample_freq=1)
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 88.0998
# Function value obtained: -0.9921
# Current minimum: -0.9928
# Iteration No: 40 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.16705482713881917, max_depth=5,
#                min_child_samples=100, n_estimators=1500, num_leaves=87,
#                random_state=42, subsample=0.20092518162161221,
#                subsample_freq=1)
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 162.3025
# Function value obtained: -0.9918
# Current minimum: -0.9928
# Iteration No: 41 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.9028901561525893,
#                learning_rate=0.015259165380528223, max_depth=6,
#                min_child_samples=63, n_estimators=1392, num_leaves=128,
#                random_state=42, subsample=0.26178480028319945,
#                subsample_freq=1)
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 204.0436
# Function value obtained: -0.9901
# Current minimum: -0.9928
# Iteration No: 42 started. Searching for the next optimal point.
# LGBMClassifier(max_depth=10, min_child_samples=100, n_estimators=1500,
#                num_leaves=2, random_state=42, subsample=0.05, subsample_freq=1)
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 96.4524
# Function value obtained: -0.9469
# Current minimum: -0.9928
# Iteration No: 43 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.15, learning_rate=0.001, max_depth=1,
#                min_child_samples=100, n_estimators=250, num_leaves=128,
#                random_state=42, subsample=0.05, subsample_freq=1)
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 30.9448
# Function value obtained: -0.8089
# Current minimum: -0.9928
# Iteration No: 44 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.15, learning_rate=0.059184600332120814,
#                max_depth=10, min_child_samples=100, num_leaves=73,
#                random_state=42, subsample=0.27075428617926006,
#                subsample_freq=1)
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 30.9158
# Function value obtained: -0.9812
# Current minimum: -0.9928
# Iteration No: 45 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.15, learning_rate=0.001, max_depth=11,
#                min_child_samples=100, n_estimators=1500, num_leaves=29,
#                random_state=42, subsample_freq=1)
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 162.2320
# Function value obtained: -0.9656
# Current minimum: -0.9928
# Iteration No: 46 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.8701011173908845,
#                learning_rate=0.0435884081358394, max_depth=7,
#                min_child_samples=100, n_estimators=1500, num_leaves=128,
#                random_state=42, subsample=0.30732071309330233,
#                subsample_freq=1)
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 253.8768
# Function value obtained: -0.9925
# Current minimum: -0.9928
# Iteration No: 47 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.15, learning_rate=0.05647723557690217,
#                max_depth=9, min_child_samples=100, n_estimators=795,
#                num_leaves=65, random_state=42, subsample=0.3961757784958953,
#                subsample_freq=1)
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 132.1664
# Function value obtained: -0.9918
# Current minimum: -0.9928
# Iteration No: 48 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.15, learning_rate=0.001, max_depth=9,
#                min_child_samples=68, n_estimators=1500, num_leaves=2,
#                random_state=42, subsample=0.05, subsample_freq=1)
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 94.0993
# Function value obtained: -0.8296
# Current minimum: -0.9928
# Iteration No: 49 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.5247646454597399,
#                learning_rate=0.015306222045896859, max_depth=11,
#                min_child_samples=1, n_estimators=1500, num_leaves=50,
#                random_state=42, subsample=0.5857892058254592, subsample_freq=1)
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 226.4250
# Function value obtained: -0.9924
# Current minimum: -0.9928
# Iteration No: 50 started. Searching for the next optimal point.
# LGBMClassifier(colsample_bytree=0.4354942947185241,
#                learning_rate=0.0734163450518934, max_depth=19,
#                min_child_samples=100, n_estimators=1500, num_leaves=66,
#                random_state=42, subsample_freq=1)
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 226.6501
# Function value obtained: -0.9926
# Current minimum: -0.9928
#           fun: -0.9927703614819258
#     func_vals: array([-0.9899205 , -0.95174241, -0.94660767, -0.91929904, -0.99213039,
#        -0.85171241, -0.95654217, -0.9780311 , -0.99217539, -0.98080096,
#        -0.79435528, -0.83783811, -0.99148543, -0.9920104 , -0.97271636,
#        -0.92019399, -0.95567722, -0.99237538, -0.99277036, -0.9819159 ,
#        -0.99211039, -0.98974051, -0.97229139, -0.98568572, -0.99212539,
#        -0.91335933, -0.99188041, -0.99245038, -0.93899305, -0.97069647,
#        -0.88317584, -0.99261037, -0.99174041, -0.96617669, -0.98617569,
#        -0.99210039, -0.99171041, -0.97448128, -0.99210539, -0.99183041,
#        -0.9900855 , -0.94692765, -0.80885456, -0.98121594, -0.96557672,
#        -0.99251037, -0.99182541, -0.82958852, -0.99236038, -0.99263037])
#        models: [GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5) + WhiteKernel(noise_level=1),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542)]
#  random_state: RandomState(MT19937) at 0x277CA1CB840
#         space: Space([Integer(low=100, high=1500, prior='uniform', transform='normalize'),
#        Integer(low=1, high=20, prior='uniform', transform='normalize'),
#        Real(low=0.001, high=0.1, prior='log-uniform', transform='normalize'),
#        Integer(low=2, high=128, prior='uniform', transform='normalize'),
#        Integer(low=1, high=100, prior='uniform', transform='normalize'),
#        Real(low=0.05, high=1.0, prior='uniform', transform='normalize'),
#        Real(low=0.15, high=1.0, prior='uniform', transform='normalize')])
#         specs: {'args': {'func': <function model_eval at 0x00000277CA301790>, 'dimensions': Space([Integer(low=100, high=1500, prior='uniform', transform='normalize'),
#        Integer(low=1, high=20, prior='uniform', transform='normalize'),
#        Real(low=0.001, high=0.1, prior='log-uniform', transform='normalize'),
#        Integer(low=2, high=128, prior='uniform', transform='normalize'),
#        Integer(low=1, high=100, prior='uniform', transform='normalize'),
#        Real(low=0.05, high=1.0, prior='uniform', transform='normalize'),
#        Real(low=0.15, high=1.0, prior='uniform', transform='normalize')]), 'base_estimator': GaussianProcessRegressor(kernel=1**2 * Matern(length_scale=[1, 1, 1, 1, 1, 1, 1], nu=2.5),
#                          n_restarts_optimizer=2, noise='gaussian',
#                          normalize_y=True, random_state=1608637542), 'n_calls': 50, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'gp_hedge', 'acq_optimizer': 'auto', 'x0': None, 'y0': None, 'random_state': RandomState(MT19937) at 0x277CA1CB840, 'verbose': True, 'callback': [<skopt.callbacks.CheckpointSaver object at 0x00000277CA2F9250>, <skopt.callbacks.VerboseCallback object at 0x00000277CA2F9910>], 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': -1, 'model_queue_size': None}, 'function': 'base_minimize'}
#             x: [844, 16, 0.026258313312433123, 128, 100, 1.0, 0.3723285664428486]
#       x_iters: [[1215, 4, 0.036256176345762295, 77, 45, 0.14497617002710278, 0.5403615581709872], [567, 4, 0.020034427927560734, 9, 72, 0.9416250735649628, 0.15066195096486218], [1489, 13, 0.01672269700618368, 3, 3, 0.5485359272454697, 0.48988182595796725], [165, 20, 0.0029210748185657135, 13, 62, 0.41333889170380467, 0.9857462529357701], [753, 17, 0.022941144328643994, 59, 2, 0.9450916679006104, 0.6287949851687085], [640, 1, 0.002895927274708839, 32, 69, 0.62949682489349, 0.8582156749757399], [343, 8, 0.0023145798905204883, 97, 43, 0.24754457972477945, 0.6325452786469928], [144, 17, 0.007934293594590601, 52, 93, 0.7409083960635999, 0.42755965348496006], [899, 11, 0.08362652463906246, 108, 75, 0.5627075257696259, 0.648738490814271], [1451, 13, 0.0035644979070394624, 39, 17, 0.06485458640413425, 0.5098912586004143], [993, 20, 0.1, 128, 29, 0.06966321655840604, 0.5030495959432745], [1450, 17, 0.1, 128, 12, 0.21919697706191216, 0.6661666610160389], [131, 10, 0.1, 57, 77, 0.5513188940159042, 0.7377877973043283], [323, 12, 0.1, 121, 15, 0.8699800765203968, 0.9012002936834459], [687, 20, 0.001, 125, 54, 1.0, 0.9245595354691893], [911, 2, 0.006871855124236871, 61, 2, 0.05, 0.3625912236164674], [753, 13, 0.0024469515641850565, 128, 90, 1.0, 0.3157779998862144], [1244, 6, 0.1, 128, 27, 0.4912856722761596, 0.8346026835841351], [844, 16, 0.026258313312433123, 128, 100, 1.0, 0.3723285664428486], [100, 18, 0.008959422875679027, 128, 100, 1.0, 0.15], [1500, 4, 0.09453787327259737, 128, 100, 0.1958903538182859, 0.5409240396822818], [1462, 7, 0.041601335130940525, 102, 72, 0.05, 0.8661207955631381], [761, 12, 0.001, 128, 100, 0.05, 0.15], [1500, 9, 0.1, 128, 100, 0.7172056197226296, 0.24777640469546414], [1132, 18, 0.1, 50, 59, 1.0, 0.9917714819178709], [188, 1, 0.1, 128, 84, 1.0, 1.0], [1500, 7, 0.03945487533160144, 90, 82, 0.31156036945715576, 0.15], [1484, 10, 0.1, 51, 36, 0.05, 0.15791525716686064], [1500, 8, 0.001, 98, 1, 1.0, 0.30934758783654365], [107, 5, 0.0840056445152498, 39, 1, 0.14556129033486065, 0.3598061381279266], [100, 16, 0.1, 2, 1, 1.0, 1.0], [1500, 20, 0.1, 90, 100, 1.0, 0.1838182704709469], [1500, 17, 0.1, 76, 100, 1.0, 0.9138550161303558], [1500, 20, 0.001, 72, 57, 1.0, 1.0], [544, 4, 0.1, 88, 22, 0.05, 0.561651824315158], [605, 15, 0.051216405326953415, 110, 100, 1.0, 0.15], [1500, 8, 0.04830404437848275, 67, 29, 0.12059109103353524, 1.0], [1500, 10, 0.1, 93, 1, 0.6708115536972049, 1.0], [520, 11, 0.071203188922792, 45, 100, 0.32304875857647053, 0.15], [1500, 5, 0.1, 87, 100, 0.20092518162161221, 0.16705482713881917], [1392, 6, 0.015259165380528223, 128, 63, 0.26178480028319945, 0.9028901561525893], [1500, 10, 0.1, 2, 100, 0.05, 1.0], [250, 1, 0.001, 128, 100, 0.05, 0.15], [100, 10, 0.059184600332120814, 73, 100, 0.27075428617926006, 0.15], [1500, 11, 0.001, 29, 100, 1.0, 0.15], [1500, 7, 0.0435884081358394, 128, 100, 0.30732071309330233, 0.8701011173908845], [795, 9, 0.05647723557690217, 65, 100, 0.3961757784958953, 0.15], [1500, 9, 0.001, 2, 68, 0.05, 0.15], [1500, 11, 0.015306222045896859, 50, 1, 0.5857892058254592, 0.5247646454597399], [1500, 19, 0.0734163450518934, 66, 100, 1.0, 0.4354942947185241]]

# %%
# check best parameters

result.x
# Out:
# [844, 16, 0.026258313312433123, 128, 100, 1.0, 0.3723285664428486]

# %% [markdown]
# ## 8.2 Final Model

# %%
params = {'n_estimators' : 844,
            'max_depth' : 16,
            'learning_rate' : 0.026258,
            'num_leaves' : 128,
            'min_child_samples' : 100,
            'subsample' : 1.0,
            'colsample_bytree' : 0.372328}

# LGBM Model
lgbm_model = LGBMClassifier(n_jobs=-1, random_state=42, subsample_freq=1)
lgbm_model.set_params(**params)
lgbm_model.fit(x_train_res, y_train_res)

# results of train dataset
y_pred = lgbm_model.predict_proba( x_test )

# %%
# ------- check result--------

df8 = x_testm.copy()
df8['response'] = y_testm.copy()

# propensity score
df8['score'] = y_pred[:, 1].tolist()

# sort clients by propensity score
df8 = df8.sort_values( 'score', ascending=False )

# compute precision and recall at 20.000 k
metrics, data = precision_recall_at_k(df8)

# organize results
metrics = pd.DataFrame(metrics)
metrics = metrics.T
metrics['model_name'] = 'LGBM_Model'
metrics.columns = ['precision_at_K', 'recall_at_K', 'model_name']
metrics = metrics[['model_name', 'precision_at_K', 'recall_at_K']]
metrics
# Out:
#    model_name  precision_at_K  recall_at_K
# 0  LGBM_Model           0.328        0.726

# %%
ft_result = runCrossValidation(lgbm_model, x_train_res, y_train_res, n_splits=10, top_k=20000, verbose=False)
ft_result
# Out:
#                 mean   std
# precision_at_k 0.993 0.002
# recall_at_k    0.853 0.001
# accuracy_score 0.923 0.001

# %%
data = gain_lift_curve(y_pred, y_test)

# %% [markdown]
# # 9.0 Tradução e interpretação do erro

# %% [markdown]
# ## 9.1 Bussiness Performance

# %% [markdown]
# ## 9.2 Total Performance

# %% [markdown]
# ## 9.3 Machine Learning Performance

# %% [markdown]
# # 10.0 Deploy model to production
